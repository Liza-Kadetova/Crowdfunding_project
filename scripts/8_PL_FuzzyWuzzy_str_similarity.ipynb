# %% [markdown]
# # Разметка текстов сборов на адресные и неадресные по списку имен

# %% [markdown]
# ### Проблема
#
# Ранее с помощью библиотеки DeepPavlov из текстов датасета были извлечены (предполагаемые) имена людей и животных, а в датасет добавлена отдельная колонка со списком (для каждого текста) извлеченных имен или пустым списком, если имен не нашлось. Это было сделано для того, чтобы дальше определить, является ли сбор адресным или нет. Под адресными подразумеваются сборы на помощь конкретному человеку или животному. На краудфандинговой площадке все сборы являются целевыми, но не все адресными.
#
# Но просто по наличию имен в тексте оказалось невозможно однозначно сказать, является ли сбор адресным или нет. Во-первых, модель часто ошибается и считает именами людей, например, названия организаций или лекарств. Во-вторых, даже при правильном определении имена могут быть случайными: имена волонтеров, врачей, сотрудников благотворительных организаций и так далее.
#
# Как правило, в текстах адресных сборов одно и то же имя (адресата сбора), упоминается несколько раз. Можно было бы предположить, что если одно и то же имя употребляется более n раз, то сбор является адресным. Но возникает проблема: как определить количество упоминаний, учитывая что одно имя может использоваться в разных словоизменительных и словообразовательных формах: Николай, Коля, Коленька…
#
# ### Решение
# Если проблемы словоизменения может решить лемматизация, то с разными словоформами имен не справляется ни лемматизация, ни стемминг. Убедившись в этом на практике, я предположила, что решить эту проблему можно с помощью **сравнения по расстоянию Левенштейна**. Можно сказать, что задача была решена достаточно успешно. Ниже приводится скрипт с использованием библиотеки Fuzzy Wuzzy.
#
# **FuzzyWuzzy** это библиотека для Python, которая используется для сопоставления строк. В основе лежит метрика - Расстояние Левенштейна. Библиотека используется, в частности, для определения близости смысла разных предложений в чат-ботах. Мы будем сравнивать не предложения, а слова.

# %%
# !pip install "fuzzywuzzy"
# !pip install "python-Levenshtein"
# Out:
# Requirement already satisfied: fuzzywuzzy in /Users/liza/my_new_env/lib/python3.7/site-packages (0.17.0)
# Collecting python-Levenshtein
#   Downloading python-Levenshtein-0.12.0.tar.gz (48 kB)
#      |████████████████████████████████| 48 kB 498 kB/s eta 0:00:01
# Requirement already satisfied: setuptools in /Users/liza/my_new_env/lib/python3.7/site-packages (from python-Levenshtein) (46.4.0)
# Building wheels for collected packages: python-Levenshtein
#   Building wheel for python-Levenshtein (setup.py) ... done
#   Created wheel for python-Levenshtein: filename=python_Levenshtein-0.12.0-cp37-cp37m-macosx_10_9_x86_64.whl size=79247 sha256=64d83a1a4bc84f3790ef9e67462a6e91014a1636df141bd26bc616411c541515
#   Stored in directory: /Users/liza/Library/Caches/pip/wheels/f0/9b/13/49c281164c37be18343230d3cd0fca29efb23a493351db0009
# Successfully built python-Levenshtein
# Installing collected packages: python-Levenshtein
# Successfully installed python-Levenshtein-0.12.0

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
import ast # The ast module helps Python applications to process trees of the Python abstract syntax grammar

# %% [markdown]
# \
# У библиотеки fuzzywuzzy есть разные методы. [Краткая статья с примерами.](https://www.geeksforgeeks.org/fuzzywuzzy-python-library/) Сравним их на нашей задаче.⬇︎

# %%
# Списки для тестов
# Примечание: не стоит называть список просто list, это убьет (перепишет) втроенную функцию list!

list1 = ['Наташа','Дима', 'Наташи', 'Наталья','Дима', 'Димы', 'Дима', 'Дима', 'Димы', 'Лиза']
list2 = ['Ильнар', 'Кыш', 'Деда', 'Деда', 'Кыш', 'Снегурочки', 'Кар', 'Яна', 'Шурале', 'Шайтан', 'Убырлы', 'Баба', 'Аждаха', 'Змей', 'Батыр', 'Алтынчеч', 'Златовласка', 'Тахир', 'Зухра', 'Ромео', 'Деда', 'Кыш', 'Кыш', 'Кар', 'Дед', 'Кыш', 'Деда', 'Снегурочки']
list3 = ['Надежда', 'Островка', 'Островка']
list4 = ['Наташа', 'Даша']
list5 = sorted(list1) # сортирует по алфавиту

# %%
# Сравним разные методы
# На совсем разных именах:

print(fuzz.ratio('Дмитрий', 'Огабек'))
print(fuzz.token_sort_ratio('Дмитрий', 'Огабек'))
print(fuzz.partial_ratio('Дмитрий', 'Огабек')) # ищет по наименьшей строке
# Out:
# 0
# 0
# 0

# %%
# На разных формах одного имени:

print(fuzz.ratio('Дмитрий', 'Дима'))
print(fuzz.token_sort_ratio('Дмитрий', 'Дима'))
print(fuzz.partial_ratio('Дмитрий', 'Дима'))
# Out:
# 36
# 36
# 50

# %% [markdown]
# \
# Методы fuzzy принимают только строки, не список. Поэтому нужно перебирать имена в цикле и сравнивать попарно. На выходе мы получим список коэффициентов - и посчитаем среднее для каждого. Проверим разные методы на одном и том же списке list1. ⬇︎

# %%
# здесь будет ошибка, т.к. подали список

print(fuzz.ratio(list1))
print(fuzz.token_sort_ratio(list1))
print(fuzz.partial_ratio(list1))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-384-75565c83ecc3> in <module>
#       1 # здесь будет ошибка, т.к. подали список
#       2
# ----> 3 print(fuzz.ratio(list1))
#       4 print(fuzz.token_sort_ratio(list1))
#       5 print(fuzz.partial_ratio(list1))
#
# ~/my_new_env/lib/python3.7/site-packages/fuzzywuzzy/utils.py in decorator(*args, **kwargs)
#      34     @functools.wraps(func)
#      35     def decorator(*args, **kwargs):
# ---> 36         if args[0] is None or args[1] is None:
#      37             return 0
#      38         return func(*args, **kwargs)
#
# IndexError: tuple index out of range

# %%
# fuzz.ratio

a = []
#i=0
for i in range(len(list1)-1): # без вычитания единицы с конца в последней паре будет ошибка out of range
    a.append(fuzz.ratio(list1[i], list1[i+1])) # берем первое слово, сравниваем со следующим по порядку, потом его - со следующим за ним и т.д.
    #i = i+1
print(a) #список коэффициентов попарного сравнения
print(sum(a)/len(a)) # считаем среднее
# Out:
# [20, 20, 62, 18, 75, 75, 100, 75, 25]
# 52.22222222222222

# %%
# fuzz.partial_ratio

a = []
#i=0
for i in range(len(list1)-1):
    a.append(fuzz.partial_ratio(list1[i], list1[i+1]))
    #i = i+1
print(a)
print(sum(a)/len(a))
# Out:
# [25, 33, 67, 25, 75, 75, 100, 75, 25]
# 55.55555555555556

# %%
# fuzz.token_sort_ratio
# Результат такой же, как у просто ratio, что логично, т.к. у нас не предложения, а слова, поэтому сортировать в строке нечего. 

a = []
#i=0
for i in range(len(list1)-1):
    a.append(fuzz.token_sort_ratio(list1[i], list1[i+1]))
    #i = i+1
print(a)
print(sum(a)/len(a))
# Out:
# [20, 20, 62, 18, 75, 75, 100, 75, 25]
# 52.22222222222222

# %%
# сортированный по алфавиту список list5 = sorted(list1)
# ratio
a = []
#i=0
for i in range(len(list5)-1):
    a.append(fuzz.ratio(list5[i], list5[i+1]))
    #i = i+1
print(a)
print(sum(a)/len(a))
# Out:
# [100, 100, 100, 75, 100, 25, 18, 62, 83]
# 73.66666666666667

# %%
# сортированный по алфавиту список list5 = sorted(list1)
# partial_ratio

a = []
i=0
for i in range(len(list5)-1):
    a.append(fuzz.partial_ratio(list5[i], list5[i+1]))
    i = i+1
print(a)
print(sum(a)/len(a))
# Out:
# [100, 100, 100, 75, 100, 25, 25, 67, 83]
# 75.0

# %% [markdown]
# ### Выбор метода библиотеки
#
# Видно, что результаты разных методов существенно отличаются. В нашем тестовом примере список имен скорее похож на адресный (имя Дима неслучайно повторяется так много раз). Поэтому может показаться, что чем выше для него коэффициент схожести имен, тем лучше подходит метод.
#
# Но на коэфф. могут повлиять случайные факторы, например:
# * Случайная созвучность разных имен (Лиза, Лида, Лика; Даша, Маша, Паша, Саша, Наташа vs Саша, Александр)
# * Количество имен имен в тексте (кто-то из авторов чаще, чем другие, может использовать местоимения, избегая повторов, а где-то встречается целый список артистов - участников концерта).
# * Порядок их упоминания в тексте (т.к. мы сравниваем имена попарно, если в несколько упоминаний имени Коля влезло упоминание, скажем, мамы Коли Наташи, это понизит “вес” имени адресата сбора (“Коля”), а если, по воле автора текста, имена будут плотнее сгруппированы (все про Колю в начале, а в конце комментарии мамы - повысит общий коэффициент).
#
# Поскольку мы не знаем распределение этих (и других возможных) факторов в датасете и ко всему датасету применяем один и тот же метод, выбрать идеальный не представляется возможным. Дальше я использую простой ratio.

# %% [markdown]
# ## Запускаем метод на датасете

# %%
import pandas as pd
import numpy as np

# %%
def fuzzy_mean(alist):
    #alist = sorted(alist) # сортировка списка в разных случаях приносит разный эффект, в общей массе на результат сильно не влияет
    if len(alist) > 1: #если в списке больше одного имени, иначе нет смысла сравнивать и будет ошибка: деление на 0 (len()-1 = 0)
        a = []
        i=0
        for i in range(len(alist)-1):
            a.append(fuzz.ratio(alist[i], alist[i+1]))
            i = i+1
        #print(a)
        mean = round(sum(a)/len(a)) # среднее с округлением
        if mean > 50: # этот порог можно менять, значения адр\неадресный пока не пишутся в датасет, это в другой функции
            print(alist) # смотрим на имена, чья схожесть оказалась высокой
            print("similarity rate:", mean) # и на среднее значение
            print("\n")
    else: # если в списке меньше одного имени, ничего не считай, просто записывай 0 
        mean = 0    
    return(round(mean))

# %%
# эта функция создает в датасете новую колонку, куда пишет полученное среднее схожести имен

def df_upd(df):
    df = df.assign(NamesSimRate = SIMILARITY)
    return df

# %%
# т.к. ранее при извлечении имен в датасет также записывалась разметка адресный\неадресный, этой функцией мы переписываем значения колонки на более точные

def adr_refresh(df):
    bins = [-np.inf, 50, np.inf] # 50 это значение в колонке NamesSimRate которое становится условием (границей) разметки 
                                # этот порог можно менять, но похоже, что на этом датасете такая граница оптимальная
    labels = ['False','True'] # True если сбор адресный, False если нет. 
    df['Adr'] = pd.cut(df['NamesSimRate'], bins=bins, labels=labels) # pandas.cut allows to segment and sort data values into bins
    return(df)

# %%
# %%time 

# %%time показывает время работы ячейки

if __name__ == "__main__": # в Jupyter необязательная строка
    
    mydf = pd.read_csv('/Users/liza/PycharmProjects/Planeta_project/plset_fin_upd_adr.csv')
    SIMILARITY = [] # станет колонкой датасета с ретингом схожести имен
    for names_list in mydf['Names']: # в этой колонки списки имен, извлеченных раньше
        names_list = list(ast.literal_eval(names_list)) 
        # при записи датасета имена были списком, но из файла читаются как строка. list(ast.literal_eval(names_list)) позволяет прочитать их как списки и итерироваться по ним для подсчета схожести
        
        SIMILARITY.append(fuzzy_mean(names_list))
    mydf = df_upd(mydf) # пишем в датасет рейтинг схожести имен
    mydf = adr_refresh(mydf) # переписываем колонкку с разметкой на адресные и неадресные сборы
    mydf = mydf.drop(mydf.columns[0:2], axis=1) # удаляем старые колонки с индексами, которые в pandas появляются при каждом чтении\записи датасета
    mydf.to_csv("plset_ver_010.csv") # сохраняем новый датасет в файл
# Out:
# ['Надежда', 'Островка', 'Островка']
# similarity rate: 56
#
#
# ['Сергею', 'Сергей', 'Сергей', 'Сергей', 'Сергей', 'Сергей', 'Сергей', 'Сергея', 'Сергея', 'Сергей', 'Сергея', 'Сергея']
# similarity rate: 94
#
#
# ['Вадима', 'Вадюшка', 'Вадику', 'Вадику', 'Вадик', 'Вадима', 'Вадиму']
# similarity rate: 78
#
#
# ['Алиса', 'Рентген', 'Лаки', 'Лаки', 'Лаки', 'Лаки', 'Бумеранга']
# similarity rate: 52
#
#
# ['Диана', 'Диана', 'Дианочка', 'Дианы', 'Пауль', 'Диана', 'Дианы']
# similarity rate: 60
#
#
# ['Марасакин', 'Марк', 'Марка', 'Марк', 'Марка', 'Марка', 'Марка', 'Марка', 'Марк', 'Марк', 'Марк', 'Марка', 'Марк', 'Марк', 'Марк', 'Марку', 'Марка', 'Марку']
# similarity rate: 91
#
#
# ['Ани', 'Ани']
# similarity rate: 100
#
#
# ['Алеши', 'Алеша', 'Алеша', 'Алеше', 'Лёше', 'Алеши']
# similarity rate: 65
#
#
# ['Арсению', 'Арсению', 'Гармонь', 'Арсений', 'Арсения', 'Арсений', 'Арсения', 'Арсению', 'Арсений', 'Арсений', 'Арсений', 'Арсений', 'Арсений', 'Арсений', 'Арсения', 'Сыроватский', 'Арсений', 'Арсению', 'Арсению', 'Арсения', 'Арсения']
# similarity rate: 81
#
#
# ['Муравья', 'Муравья']
# similarity rate: 100
#
#
# ['Дмитрий', 'Дмитрий', 'Дмитрий', 'Дмитрия', 'Дмитрий', 'Дарья', 'Дмитрий', 'Дмитрия', 'Дмитрия']
# similarity rate: 78
#
#
# ['Север', 'Шани', 'Шаньку', 'Шаня', 'Шанька', 'Шани', 'Шаню', 'Шани']
# similarity rate: 56
#
#
# ['Кольцова', 'Никиты', 'Никиты', 'Никита']
# similarity rate: 61
#
#
# ['Тимура', 'Софи', 'Софи', 'Софи', 'Андреасян', 'Софи', 'Роза', 'Софи', 'Софи', 'Софи', 'Софи', 'Розы', 'Софи', 'Софи', 'Софи', 'Дженнифер', 'Дарья', 'Софи', 'Софи', 'Софи', 'Софи', 'Софи', 'Софи']
# similarity rate: 62
#
#
# ['Маша', 'Маша', 'Маша', 'Маше', 'Машиной', 'Машиной']
# similarity rate: 86
#
#
# ['Валерий', 'Мария', 'Валерий', 'Валерий', 'Мария', 'Мария', 'Валерий', 'Мария', 'Шалинцевых', 'Брайлем', 'Шалинцевых']
# similarity rate: 55
#
#
# ['Воробьев', 'Павлик', 'Павлик', 'Павлик', 'Паши', 'Павлика', 'Паши']
# similarity rate: 64
#
#
# ['Исмаил', 'Елизаровых', 'Исмаилу', 'Исмаила', 'Исмаила', 'Исмаила', 'Исмаила']
# similarity rate: 68
#
#
# ['Дима', 'Диму', 'Диминых', 'Димы', 'Дима', 'Димина', 'Димина', 'Сашу', 'Диминой']
# similarity rate: 60
#
#
# ['Анна', 'Лира', 'Лира', 'Нита', 'Пиксель', 'Лиса', 'Алиса', 'Алиса']
# similarity rate: 57
#
#
# ['Фроська', 'Фроська', 'Фроське']
# similarity rate: 93
#
#
# ['Ольга', 'Николай', 'Николай', 'Николай', 'Николаем']
# similarity rate: 78
#
#
# ['Наташа', 'Вити', 'Вити', 'Верднига', 'Вити', 'Витя', 'Витю', 'Витину']
# similarity rate: 57
#
#
# ['Анна', 'Анну', 'Анна']
# similarity rate: 75
#
#
# ['Илья', 'Илья', 'Илье', 'Илья', 'Ильи', 'Илья', 'Илья', 'Илье', 'Илья', 'Илью', 'Илья', 'Илье', 'Илье']
# similarity rate: 81
#
#
# ['Грегори', 'Лоранс', 'Пьер', 'Грегори', 'Грегори', 'Грегори']
# similarity rate: 57
#
#
# ['Константин', 'Константин', 'Константин', 'Константин', 'Константин', 'Константин', 'Юрия', 'Ксении', 'Константин', 'Константину', 'Константина']
# similarity rate: 77
#
#
# ['Женя', 'Жени', 'Жени', 'Оксана', 'Жене', 'Женя', 'Оксане', 'Жени', 'Жене', 'Жене', 'Жени', 'Жене', 'Жени', 'Жени']
# similarity rate: 64
#
#
# ['Света', 'Света']
# similarity rate: 100
#
#
# ['Алёша', 'Эльвира', 'Юлю', 'Эльвира', 'Алёшин', 'Эльвира', 'Алёша', 'Алёша', 'Алёши', 'Алёша', 'Алёши', 'Алёша', 'Алёша', 'Эльвире', 'Алёше']
# similarity rate: 53
#
#
# ['Юмашева', 'Вики', 'Вики', 'Вика', 'Вике']
# similarity rate: 62
#
#
# ['Йога', 'Йога', 'Джоанн']
# similarity rate: 70
#
#
# ['Илья', 'Ксюшенке', 'Аманом', 'Андрею', 'Андрею', 'Андрей', 'Андрея', 'Андрея', 'Андрею', 'Андрей', 'Андрей']
# similarity rate: 68
#
#
# ['Нины', 'Светланой', 'Светлана', 'Светлана', 'Стива', 'Билла', 'Илюше', 'Ане', 'Ване', 'Светлана', 'Светланы', 'Светлана', 'Светлана', 'Светлана', 'Светлана', 'Светланин', 'Светлана', 'Ходжкина', 'Светлана', 'Светланина', 'Светлана', 'Светланы', 'Ходжкина', 'Светлане', 'Валерий', 'Евгения']
# similarity rate: 58
#
#
# ['Насте', 'Насте', 'Настю', 'Насти', 'Насте', 'Насте', 'Настенька', 'Насте', 'Настеньку', 'Ниймеген', 'Настя', 'Насте', 'Дерипапе', 'Насти', 'Настю', 'Настя', 'Насти']
# similarity rate: 67
#
#
# ['Вика', 'Вики', 'Вике', 'Вики', 'Викино', 'Вике', 'Вика', 'Вику', 'Вика', 'Вике']
# similarity rate: 74
#
#
# ['Верднига', 'Полины', 'Полины', 'Полина', 'Полина', 'Полины', 'Полине', 'Полины', 'Полина', 'Полине']
# similarity rate: 79
#
#
# ['Вани', 'Вани', 'Ваня', 'Вани', 'Вани', 'Вани', 'Ване']
# similarity rate: 88
#
#
# ['Машу', 'Маша', 'Маше', 'Маша', 'Маша', 'Машей', 'Маша', 'Маша', 'Маши', 'Маша', 'Маше', 'Даше', 'Маша', 'Маша', 'Маша']
# similarity rate: 79
#
#
# ['Рома', 'Ромка', 'Ромы', 'Рома', 'Ромки', 'Рома', 'Рома', 'Ромы', 'Роме', 'Бепантен', 'Ромы']
# similarity rate: 63
#
#
# ['Нина', 'Никита']
# similarity rate: 60
#
#
# ['Глеба', 'Глебу', 'Глебу', 'Глеб', 'Глеб', 'Глеб', 'Глеба', 'Глеба', 'Глебу']
# similarity rate: 92
#
#
# ['Карина', 'Карину', 'Карины', 'Карина', 'Карине', 'Карины', 'Карины', 'Карине']
# similarity rate: 85
#
#
# ['Татьяна', 'Таню', 'Тане', 'Таня', 'Таня', 'Таня', 'Таня', 'Матвей', 'Макар', 'Макар', 'Матвей', 'Макар', 'Матвей', 'Танина', 'Таня', 'Макар', 'Макар', 'Матвей', 'Матвей', 'Акар', 'Макара', 'Матвей']
# similarity rate: 58
#
#
# ['Надежда', 'Надежда']
# similarity rate: 100
#
#
# ['Екатерина', 'Елена']
# similarity rate: 57
#
#
# ['Катя', 'Катя', 'Катюша', 'Кати', 'Кати']
# similarity rate: 80
#
#
# ['Дани', 'Дане', 'Дани', 'Дани']
# similarity rate: 83
#
#
# ['Варю', 'Варя', 'Владимир', 'Тимофей', 'Дружинин', 'Владимир', 'Вовы', 'Вову', 'Вове', 'Вова', 'Вове', 'Носов', 'Тимофею', 'Тимофей', 'Тимоша', 'Тимофей', 'Тимофея']
# similarity rate: 53
#
#
# ['Натальи', 'Наталье', 'Натальи']
# similarity rate: 86
#
#
# ['Фаина', 'Полина', 'Алиса', 'Арсений', 'Арсению', 'Сеня', 'Арсений', 'Сеня', 'Сене', 'Арсения', 'Арсения']
# similarity rate: 55
#
#
# ['Вика', 'Вика', 'Вика', 'Вика', 'Вика', 'Мамины', 'Вики']
# similarity rate: 73
#
#
# ['Ирина', 'Альбине', 'Альбина', 'Альбиной', 'Альбине', 'Альбина', 'Альбина', 'Альбины', 'Альбина']
# similarity rate: 80
#
#
# ['Артема', 'Артем', 'Артем', 'Артема', 'Улльриха', 'Артема', 'Артем', 'Артема', 'Лена', 'Артем', 'Артема', 'Артему', 'Артему']
# similarity rate: 72
#
#
# ['Витю', 'Витюшей', 'Вити', 'Витя', 'Вити', 'Витиной', 'Витиной', 'Витя', 'Витя', 'Витя', 'Вите', 'Витиной']
# similarity rate: 76
#
#
# ['Дмитрий', 'Ирина', 'Ирина', 'Ирина', 'Диме', 'Ире', 'Олеси', 'Олеси', 'Олеся', 'Татьяна', 'Олегу']
# similarity rate: 51
#
#
# ['Арсения', 'Арсения', 'Арсений', 'Арсений', 'Арсения', 'Арсений', 'Арсений', 'Арсений', 'Арсения', 'Арсением', 'Арсению', 'Арсения', 'Арсения']
# similarity rate: 91
#
#
# ['Филькевичу', 'Саша', 'Саша', 'Саше', 'Саши', 'Филькевича']
# similarity rate: 53
#
#
# ['Нина', 'Нине', 'Нина', 'Нины', 'Нинин', 'Нина', 'Нине', 'Нине', 'Валерий', 'Евгения', 'Нине', 'Нине']
# similarity rate: 64
#
#
# ['Кирилл', 'Кирилла', 'Кирилла', 'Кириллу', 'Кирилла', 'Абатацепт', 'Кириллу', 'Кирилл', 'Кирюша', 'Кирилл']
# similarity rate: 63
#
#
# ['Калитенко', 'Анастасия', 'Настя', 'Настю', 'Настя', 'Настю', 'Анастасия', 'Калитенко']
# similarity rate: 53
#
#
# ['Светлана', 'Светлана', 'Светлана', 'Наталья', 'Надежда']
# similarity rate: 68
#
#
# ['Вари', 'Варя', 'Николаевых', 'Вари', 'Варя', 'Варенька', 'Варина', 'Вари', 'Вариной']
# similarity rate: 56
#
#
# ['Виталине', 'Виталина', 'Виталине', 'Виталина', 'Виталина', 'Виталины']
# similarity rate: 90
#
#
# ['Павел', 'Дима', 'Дима', 'Дмитрию', 'Дмитрием', 'Дмитрию', 'Павел']
# similarity rate: 53
#
#
# ['Алисы', 'Алиса', 'Алиса', 'Алиса', 'Алиса', 'Алисы', 'Алисы', 'Алисе', 'Алисе', 'Неокейт', 'Нутрини', 'Алиса', 'Алису', 'Алису']
# similarity rate: 76
#
#
# ['Сонечка', 'Соне', 'Софьи', 'Соне', 'Софья', 'Сонечки', 'Сони', 'Соне']
# similarity rate: 55
#
#
# ['Страчковой', 'Маша', 'Маша', 'Маша', 'Маши', 'Маши', 'Маша', 'СМЕТА']
# similarity rate: 69
#
#
# ['Полине', 'Поли', 'Кирилл', 'Максим', 'Полина', 'Полине', 'Полину', 'Полина']
# similarity rate: 55
#
#
# ['Даниил', 'Даниил', 'Александра', 'Даниил', 'Даниил', 'Даниил', 'Даниилу', 'Даниила', 'Даниила', 'Даниила', 'Дани', 'Даниилу']
# similarity rate: 79
#
#
# ['Соня', 'Соня', 'Соню', 'Соня', 'Соне', 'Соне']
# similarity rate: 85
#
#
# ['Фаина', 'Тимур', 'Тимур', 'Тимур', 'Тимуру', 'Оксана', 'Тимур', 'Тимура', 'Тимура', 'Тимур', 'Тимура']
# similarity rate: 68
#
#
# ['Люба', 'Люба', 'Мирко', 'Люба', 'Любы', 'Люба', 'Люба', 'Мирко', 'Любовь', 'Любиной', 'Люба', 'Люба', 'Любы']
# similarity rate: 55
#
#
# ['Полина', 'Полина', 'Полина', 'Полину', 'Ирина', 'Поли', 'Полина', 'Полина', 'Поля', 'Плюшева', 'Полина', 'Поля', 'Ирина', 'Ирина', 'Полина', 'Ирина', 'Полина', 'Ирина', 'Поли', 'Полина', 'Ирина', 'Полина', 'Полины', 'Полине']
# similarity rate: 62
#
#
# ['Сережи', 'Сереже', 'Серёжа', 'Сергею', 'Сережа', 'Томатис', 'Сережа', 'Сереже', 'Сережи', 'Сереже']
# similarity rate: 61
#
#
# ['Мелиор', 'Георгий', 'Жора', 'Жора', 'Жоры', 'Жорой', 'Жоры', 'Даши', 'Даша', 'Даши', 'Дарья', 'Даша', 'Даша', 'Пьера', 'Елены', 'Толя']
# similarity rate: 53
#
#
# ['Ваней', 'Ванечка', 'Ваня', 'Ваня', 'Ванюша', 'Ваню', 'Ваня']
# similarity rate: 73
#
#
# ['Монькаева', 'Емлина', 'Алина', 'Алина', 'Емлина']
# similarity rate: 68
#
#
# ['АГНИЯ', 'Агнии', 'Агния', 'Агния', 'Ангелины', 'Агнии', 'Агнюши', 'Агнии', 'Ангелина', 'Агнию', 'Войта', 'Агнии', 'Агнии']
# similarity rate: 52
#
#
# ['Ксюша', 'Ксюша', 'Ксюши', 'Ксюше', 'Настей', 'Ксюши', 'Ксюша', 'Ксюша', 'Ксюша', 'Ксюша', 'Ксюши', 'Ира', 'Шамарина', 'Ксюша', 'Ксюша', 'Ксюше', 'Шамарина', 'Сальниковых', 'Ксюша']
# similarity rate: 58
#
#
# ['Кристины', 'Юлия', 'Кристина', 'Кристина', 'Кристина', 'Кристине', 'Юлия', 'Юлия', 'Кристина', 'Кристина', 'Юли', 'Кристины', 'Кристине', 'Кристина', 'Юля', 'Кристине', 'Кристина']
# similarity rate: 54
#
#
# ['Алексея', 'Алексею', 'Алексей', 'Алексею', 'Алеша', 'Алеша', 'Алексей', 'Алеша', 'Алексей', 'Алешу', 'Алеше', 'Алексея', 'Леше']
# similarity rate: 66
#
#
# ['Льву', 'Льва', 'Лев', 'Лев', 'Льва', 'Льву', 'Львом', 'Лев', 'Лев', 'Льву', 'Зимичей', 'Льва']
# similarity rate: 58
#
#
# ['Андрей', 'Андрею', 'Кабуки', 'Кабуки', 'Берниус', 'Андрей', 'Андрюшкины', 'Андрей', 'Андрею', 'Андрея', 'Андрею']
# similarity rate: 56
#
#
# ['Алиночку', 'Сенченко', 'Альбины', 'Алине', 'Алина', 'Алина', 'Алина', 'Алина', 'Алина', 'Алина', 'Андрей']
# similarity rate: 72
#
#
# ['Роял', 'Лоу', 'Роял', 'Канин', 'Роял', 'Роял', 'Ренал', 'Роял', 'Ренал', 'Роял', 'Роял', 'Роял', 'Роял', 'Роял']
# similarity rate: 56
#
#
# ['Насти', 'Насти', 'Насти', 'Насте', 'Насти', 'Насти']
# similarity rate: 92
#
#
# ['Ярослав', 'Яся', 'Ярославу', 'Ярослав', 'Ярослава', 'Ярославу', 'Ярослав']
# similarity rate: 74
#
#
# ['Лизы', 'Лизе', 'Лизе', 'Лизе', 'Лизы', 'Лиза', 'Лиза', 'Ирины', 'Лизу', 'Лизы', 'Лизе']
# similarity rate: 72
#
#
# ['Колю', 'Коля', 'Коле', 'Коля']
# similarity rate: 75
#
#
# ['Маша', 'Маруся', 'Маши', 'Маша', 'Машиной', 'Маши', 'Маши', 'Маше', 'Богацких']
# similarity rate: 59
#
#
# ['Рогозин', 'Егор', 'Егор', 'Егор', 'Егора', 'Егора', 'Егором', 'Егора']
# similarity rate: 82
#
#
# ['Догпорт', 'Догпорту']
# similarity rate: 93
#
#
# ['Марьям', 'Марьям', 'Марьям', 'Марьям', 'Марьям', 'Гасановых', 'Марьям', 'Марьям']
# similarity rate: 75
#
#
# ['Илья', 'Егор', 'Аманом', 'Егора', 'Коагучек', 'Егор', 'Егора', 'Егор', 'Егор', 'Егора', 'Егор', 'Егор', 'Егору', 'Коагучек', 'Егору', 'Коагучек', 'Егору']
# similarity rate: 52
#
#
# ['Амир', 'Амир', 'Амира', 'Амир', 'Амиру', 'Амира', 'Амира', 'Амира', 'Амир']
# similarity rate: 92
#
#
# ['Станиславу', 'Стас', 'Стаса', 'Стаса', 'Стас', 'Стаса', 'Станислав', 'Стаса', 'Стас']
# similarity rate: 82
#
#
# ['Фаина', 'Тимур', 'Тимур', 'Полина', 'Полина', 'Полина', 'Полине', 'Полины']
# similarity rate: 72
#
#
# ['Паша', 'Паше', 'Паши', 'Паши', 'Паша', 'Паше', 'Паши', 'Пашину']
# similarity rate: 79
#
#
# ['Алина', 'Алины', 'Алине', 'Алины', 'Алины', 'Алину', 'Алины', 'Алины']
# similarity rate: 86
#
#
# ['Никите', 'Никита', 'Гепатита', 'Никита']
# similarity rate: 56
#
#
# ['Анастасии', 'Анны', 'Анны']
# similarity rate: 66
#
#
# ['Петя', 'Пети', 'Пете', 'Петя', 'Петя', 'Петя', 'Крокодилы', 'Петя', 'Петя', 'Пети', 'Вами', 'Ганжиных', 'Пете', 'Пете', 'Пете']
# similarity rate: 61
#
#
# ['Фредди', 'Фредди']
# similarity rate: 100
#
#
# ['Ксюша', 'Ксюше', 'Шерешевского', 'Ксении', 'Ксюши', 'Ксении', 'Ксюши', 'Ксюша', 'Ксюше']
# similarity rate: 55
#
#
# ['Лиза', 'Лизы', 'Лиза', 'Лиза', 'Лиза', 'Агнии', 'Джанни', 'Лиза', 'Лизу', 'Лиза', 'Лизы', 'Лизе', 'Лизы', 'Лизе', 'Елизавета', 'Лизы']
# similarity rate: 64
#
#
# ['Петуховых', 'Полине', 'Полина', 'Полина', 'Полине', 'Полины', 'Полина']
# similarity rate: 76
#
#
# ['Саше', 'Саша', 'Саша', 'Сашу', 'Монтессори', 'Саша', 'Мария', 'Саши', 'Саше', 'Саша', 'Мария', 'Амбу', 'Саша', 'Саша', 'Саши', 'Саше', 'Саши', 'Саше']
# similarity rate: 52
#
#
# ['Даниил', 'Ольги', 'Ольги']
# similarity rate: 59
#
#
# ['Гентингона', 'Гентингтона', 'Гентингтона']
# similarity rate: 98
#
#
# ['Вера', 'Винни', 'Вера', 'Вера', 'Веры', 'Веры']
# similarity rate: 64
#
#
# ['Алена', 'Андрей', 'Алёна', 'Алена']
# similarity rate: 51
#
#
# ['Кевин', 'Кевин', 'Кевин', 'Кевин', 'Кевин', 'Алиса', 'Алису', 'Алиса', 'Аршавин', 'Аршавин', 'Аршавина', 'Аршавин', 'Аршавин', 'Кевин', 'Аршавин', 'Алиса']
# similarity rate: 75
#
#
# ['Виталий', 'Виталий', 'Виталий', 'Виталию']
# similarity rate: 95
#
#
# ['Настя', 'Насти', 'Настя', 'Настя', 'Настя', 'Настя', 'Настя', 'Чуда', 'Настя', 'Насти', 'Настя', 'Настину', 'Настя', 'Настей', 'Настя', 'Насти', 'Настя', 'Настина', 'Закарулис', 'Настя', 'Настю', 'Насти', 'Настя', 'Настя', 'Настя', 'Насте', 'Насте']
# similarity rate: 75
#
#
# ['Лёша', 'Лёша', 'Лёшеньку', 'Лёша']
# similarity rate: 67
#
#
# ['Алиса', 'Алиса', 'Алиса', 'Алисы', 'Алисе', 'Алисы', 'Алиса', 'Алису', 'М', 'Алисе', 'Алисы', 'Алиса', 'Ирина', 'Алисы']
# similarity rate: 63
#
#
# ['Диана', 'Диана', 'Диана']
# similarity rate: 100
#
#
# ['Юрий', 'Мамлеев', 'Юрий', 'Юрий', 'Юрий', 'Юрий', 'Юрия', 'Андрея', 'Мамлеева']
# similarity rate: 54
#
#
# ['Арине', 'Верднига', 'Арина', 'Аринины', 'Арина', 'Арина', 'Арина', 'Арины', 'Арины', 'Арина', 'Арининой', 'Арины']
# similarity rate: 72
#
#
# ['Миланку', 'Миланке', 'Миланочке']
# similarity rate: 87
#
#
# ['Маргарита', 'Кати', 'Ани', 'Даши', 'Маргарита', 'Маргарите', 'Маргарите']
# similarity rate: 52
#
#
# ['Леночка', 'Леночка', 'Лены', 'Лены', 'Лену', 'Лене', 'Верднига', 'Лена', 'Лена', 'Лены', 'Оксана', 'Лена']
# similarity rate: 66
#
#
# ['Кирилл', 'Кирилл', 'Кириллу', 'Кирилла', 'Кирилла', 'Кирилл', 'Кирилл', 'Кирилла', 'Кирилла', 'Кириллу', 'Сергей', 'Кириллу', 'Кириллом', 'Кирилл', 'Авиценна', 'ВАМ', 'Кирилл']
# similarity rate: 67
#
#
# ['Игоря', 'Игорь', 'Игорю', 'Игорь', 'Игорь', 'Игорем']
# similarity rate: 83
#
#
# ['Верочки', 'Вера', 'Верочка', 'Скороходовых', 'Вера', 'Веры', 'Вере', 'Вере', 'Веры']
# similarity rate: 61
#
#
# ['Казаков', 'Саше', 'Сашу', 'Сашу', 'Сашина', 'Саше', 'Саше', 'Иванова', 'Александра']
# similarity rate: 58
#
#
# ['Тэя', 'Тэя', 'Тэя', 'Тэя', 'Тэе', 'Тэя', 'Тэи', 'Тэи']
# similarity rate: 86
#
#
# ['Илюша', 'Илюше', 'Илюша', 'Илюша', 'Илюши', 'Илье', 'Илюшином', 'Илюше', 'Илюша']
# similarity rate: 70
#
#
# ['Тагира', 'Тагир', 'Тагиру', 'Тагир', 'Амиле', 'Тагира', 'Тагир', 'Тагир', 'Тагир']
# similarity rate: 75
#
#
# ['Артеменко', 'Данил', 'Данил', 'Данилу', 'Данил']
# similarity rate: 74
#
#
# ['Яромиром', 'Яромира', 'Яромир', 'Яромира', 'Яромира', 'Яромиру']
# similarity rate: 90
#
#
# ['Алиса', 'Алисе', 'Алиса', 'Алиса', 'Азарян', 'Алисе']
# similarity rate: 63
#
#
# ['Глеба', 'Глеб', 'Глебушка', 'Глеб', 'Глеба', 'Глеба', 'Глебу']
# similarity rate: 82
#
#
# ['Даня', 'Дани', 'Данин', 'Даня', 'Даня', 'Даня', 'Вера', 'Даню', 'Дане', 'Помпа', 'Даня', 'Дане', 'Даню', 'Дани', 'Веры', 'Вера', 'Веры', 'Дани', 'Даню']
# similarity rate: 58
#
#
# ['Таня', 'Эдвардса', 'Тани', 'Таня', 'Таню', 'Таня', 'Таня', 'Танины', 'Тани', 'Тани', 'Таня', 'Таня', 'Таня', 'Таня', 'Танино', 'Танину', 'Таня']
# similarity rate: 74
#
#
# ['Дима', 'Дима', 'Диме', 'Димы', 'Диме', 'Диме', 'Смирновых', 'Димы']
# similarity rate: 67
#
#
# ['Данила', 'Дарья', 'Данилка', 'Данила', 'Дани', 'Данила', 'Данила', 'Даней', 'Данилке']
# similarity rate: 68
#
#
# ['Полина', 'Полининых', 'Полина', 'Полины', 'Полины', 'Полины', 'Полины', 'Полины', 'Полиной', 'Полины', 'Полины', 'Полина']
# similarity rate: 87
#
#
# ['Тимоша', 'Бобылёвых', 'Тимоша', 'Тимоше', 'Тимофею', 'Тимоша', 'Тимоша', 'Тимоша', 'Бобылёвых']
# similarity rate: 58
#
#
# ['Катюше', 'Кати', 'Катюшу', 'Наташа', 'Катюши', 'Катюша', 'Катюша', 'Катя', 'Катюша', 'Катю', 'Катюша', 'Катюша', 'Наташа']
# similarity rate: 71
#
#
# ['Андрюша', 'Андрюши', 'Андрюшей', 'Андрей', 'Андрюше', 'Андрюшу', 'Андрюши', 'Андрюше']
# similarity rate: 84
#
#
# ['Лучик', 'Ксюше', 'Ксения', 'Ксюше', 'Ксюша', 'Ксения', 'Ксюши', 'Ксюша', 'Коляска']
# similarity rate: 51
#
#
# ['Джевейра', 'Вахтангом', 'Вахтанг', 'Вахтанг', 'Вахтанга', 'Джгаркава', 'Малаховой', 'Вахтанга', 'Вахтанга']
# similarity rate: 59
#
#
# ['Алина', 'Алиночки', 'Алине', 'Алиночке', 'Алины', 'Алины']
# similarity rate: 73
#
#
# ['Саше', 'Саша', 'Саша', 'Саше', 'Саши', 'Саша', 'Саша', 'Саше', 'Саши', 'Саша', 'Сашин']
# similarity rate: 79
#
#
# ['Тимур', 'Тимур', 'Тимура', 'Тимур', 'Тимура', 'Тимур', 'Тимур', 'Тимуром']
# similarity rate: 92
#
#
# ['Назирубону', 'Назиры', 'Эдварса', 'Назире', 'Назира', 'Назире', 'Назире']
# similarity rate: 65
#
#
# ['Полине', 'Полина', 'Полине', 'Полина', 'Полина', 'Полины', 'Полина', 'Коляска']
# similarity rate: 80
#
#
# ['Оля', 'Алекса', 'Оля', 'Оли', 'Оле', 'Оли', 'Оли', 'Оле']
# similarity rate: 59
#
#
# ['Эльдара', 'Караташ', 'Эльдар', 'Эльдар', 'Эльдар', 'Эльдар', 'Эльдар', 'Эльдару', 'Эльдару', 'Эльдара', 'Эльдар', 'Эльдар', 'Эльдар', 'Эльдару']
# similarity rate: 87
#
#
# ['Плинтуса', 'Плинтуса', 'Плинтус', 'Плинтус']
# similarity rate: 98
#
#
# ['Ярославу', 'Ярослава', 'Ярослав', 'Ярику', 'Ярику', 'Ярика']
# similarity rate: 79
#
#
# ['Дима', 'Михаилом', 'Михаила', 'Михаил']
# similarity rate: 68
#
#
# ['Василиса', 'Василисе', 'Василиса', 'Василисы']
# similarity rate: 88
#
#
# ['Алмаза', 'Валеев', 'Алмаз', 'Алмаза', 'Алмаза', 'Алмаза', 'Алмаза', 'Алмаз', 'Алмаз', 'Алмаз', 'Алмаза', 'Алмаз', 'Алмаза', 'Алмазу']
# similarity rate: 83
#
#
# ['Тамаре', 'Тамара', 'Тамары', 'Тамары', 'Тамары', 'Тамара']
# similarity rate: 90
#
#
# ['Оксана', 'Ольга', 'Саши', 'Саши']
# similarity rate: 53
#
#
# ['Димы', 'Дима', 'Дима', 'Димины', 'Диму', 'Димочка', 'Дима', 'Дима', 'Диме', 'Дима', 'Диму', 'Димины', 'Дима', 'Диму', 'Диме', 'Диме', 'Димы', 'Димы', 'Диму']
# similarity rate: 76
#
#
# ['Николашиной', 'Настя', 'Настя', 'Насти', 'Насте', 'Настенька', 'Настя', 'Настя', 'Настя', 'Настю']
# similarity rate: 77
#
#
# ['Валентине', 'Евгению', 'Валентина', 'Валентиной', 'Евгений']
# similarity rate: 52
#
#
# ['Олеси', 'Олеси', 'Олеся', 'Олеся', 'Олеся', 'Олесеньки']
# similarity rate: 87
#
#
# ['Лиана', 'Лиане', 'Лиане', 'Лиана', 'Лианы', 'Лианы']
# similarity rate: 88
#
#
# ['Л', 'Ра', 'Вадик', 'Вадика', 'Вадик', 'Вадик', 'Вадик', 'Аринка', 'Вадиму', 'Вадика', 'Вадима', 'Вадиму']
# similarity rate: 62
#
#
# ['Оли', 'Оля', 'Оле', 'Оля', 'Оли', 'Оле', 'Оле', 'Оля', 'Оля', 'Оли', 'Оле']
# similarity rate: 74
#
#
# ['Гамак', 'Лежак', 'Лежак', 'Лежак']
# similarity rate: 80
#
#
# ['Квашневской', 'Машенька', 'Маша', 'Маша', 'Маша', 'Маша', 'Машеньки', 'Машенька', 'Маши', 'Маши', 'Маше', 'Маши', 'Маши', 'Маши', 'Машеньки', 'Маше', 'Маше', 'Маше']
# similarity rate: 81
#
#
# ['Елена', 'Ирины', 'Ирина', 'Ирина', 'Ирины', 'Ирина', 'Ирине', 'Ирины', 'Ирине', 'Ирине', 'Ирины', 'Ирины']
# similarity rate: 80
#
#
# ['Джип', 'Дэна', 'Дэна', 'Дэну', 'Дэна']
# similarity rate: 69
#
#
# ['Илья', 'Ильи', 'Илья', 'Илюши', 'Илье', 'Татьяне', 'Илья', 'Илья', 'Илюша', 'Илья', 'Илья', 'Илье', 'Илье', 'Илью']
# similarity rate: 65
#
#
# ['Федору', 'Феди', 'Федя', 'Федя', 'Федя', 'Федя', 'Феди', 'Люда', 'Федя', 'Федя', 'Федин', 'Феде', 'Борькина']
# similarity rate: 66
#
#
# ['Сабрины', 'Сабриночки', 'Сабрина', 'Сабрина', 'Сабрина', 'Сабрине', 'Сабриночке']
# similarity rate: 85
#
#
# ['Алиса', 'Боня', 'Шерри', 'Лаки', 'Лаки', 'Стронгхолд', 'Стронгхолд', 'Стронгхолд', 'Стронгхолда']
# similarity rate: 52
#
#
# ['Гаврильчева', 'Тимуре', 'Тимур', 'Тимурчик', 'Тимур', 'Тимур']
# similarity rate: 74
#
#
# ['Шани', 'Шаню']
# similarity rate: 75
#
#
# ['Маргариты', 'Маргарита', 'Демченко', 'Демченко', 'Маргарита', 'Маргариты', 'Маргарита', 'Ольга', 'Маргарита', 'Маргарите', 'Маргарита', 'Маргарита', 'Демченко', 'Маргарите', 'Маргаритки']
# similarity rate: 57
#
#
# ['Садыкову', 'Магомед', 'Магомед']
# similarity rate: 64
#
#
# ['Ариши', 'Ариночка', 'Ариша', 'Ариночке', 'Арине', 'Арина', 'Арине']
# similarity rate: 65
#
#
# ['Витя', 'Витины', 'Вите', 'Витю', 'Витю', 'Вите', 'Витя', 'Витя', 'Вите', 'Витя', 'Вити', 'Вити']
# similarity rate: 79
#
#
# ['Сабина', 'Сабина', 'Сабины', 'Сабину', 'Сабины']
# similarity rate: 87
#
#
# ['Ярослава', 'Ярик', 'Ярослава', 'Анастасия', 'Ярослав', 'Ярославу', 'Ярослав', 'Ярик', 'Ярик', 'Ярославу', 'Ярика', 'Ярика', 'Ярославу']
# similarity rate: 54
#
#
# ['Кайзумовых', 'Василиса', 'Василисы', 'Василисе', 'Василисе']
# similarity rate: 72
#
#
# ['Трезору', 'Трезору', 'Трезору', 'Светланы']
# similarity rate: 71
#
#
# ['Алексей', 'Полине', 'Полины', 'Полина', 'Полина', 'Полина', 'Полина', 'Полины', 'Полина', 'Полине', 'Полины']
# similarity rate: 83
#
#
# ['Азалии', 'Азалия', 'Азалии', 'Азалия', 'Азалии', 'Азалии']
# similarity rate: 86
#
#
# ['Эмми', 'Эмми', 'Эмми', 'Эмми', 'Эмми']
# similarity rate: 100
#
#
# ['Мари', 'Мари', 'Степу', 'Степу', 'Мари', 'Мари', 'Мари', 'Мари', 'Мари', 'Мари', 'Мари', 'Мари']
# similarity rate: 82
#
#
# ['Даша', 'Даши', 'Даша', 'Даша', 'Даша', 'Даша', 'Даша', 'Даша', 'Даше', 'Даши', 'Бепантен', 'Бепантен', 'Мепилекс', 'Мепилекс', 'Бинты', 'Пронтосан', 'Папе', 'Уховой', 'Даши', 'Рома', 'Даши']
# similarity rate: 59
#
#
# ['Лебедева', 'Захар', 'Захару', 'Захар', 'Захар']
# similarity rate: 74
#
#
# ['Егор', 'Егора', 'Егор', 'Егора', 'Егор', 'Егор', 'Егор', 'Турнера', 'Егора', 'Егор', 'Егора', 'Егору', 'Егора', 'Егора', 'Егор', 'Егор']
# similarity rate: 82
#
#
# ['Стефания', 'Стеши', 'Стеша', 'Стешиной', 'Стефания', 'Стеши', 'Стефании', 'Стеши', 'Стешу', 'Стефания', 'Стефании', 'Стефанию']
# similarity rate: 67
#
#
# ['Мурад', 'Мурад', 'Мурадом', 'Мурада', 'Гиршпрунга', 'Мурадом', 'Мурада', 'Мурада', 'Мурад', 'Мурад', 'Мурада']
# similarity rate: 77
#
#
# ['Насти', 'Настя', 'Настину', 'Настя', 'Настю', 'Насти', 'Настя', 'Насте', 'Настя', 'Насти', 'Насти', 'Настя', 'Настя', 'Насте', 'Настеньку', 'Насти', 'Настя', 'Настя', 'Насти', 'Насти', 'Настей', 'Насте']
# similarity rate: 81
#
#
# ['Сергей', 'Денис', 'Денис', 'Денис', 'Денис', 'Юлия', 'Дениса', 'Дениса', 'Денису', 'Дениса']
# similarity rate: 70
#
#
# ['Насти', 'Маши', 'Настя', 'Настя', 'Маше', 'Маша']
# similarity rate: 53
#
#
# ['Даниил', 'Дани', 'Даниила', 'Дюшенна', 'Даня', 'Даниил', 'Дани', 'Даниил', 'Даниил', 'Даниилу', 'Даниила']
# similarity rate: 72
#
#
# ['Фаина', 'Тимур', 'Полина', 'Алиса', 'Алисе', 'Алиса', 'Алиса', 'Алисы', 'Алисы', 'Дашка', 'Ксения', 'Алисы', 'Алисе', 'Алисы']
# similarity rate: 55
#
#
# ['Матвей', 'Матвея', 'Татьяны', 'Бабушки', 'Матвею', 'Матвею']
# similarity rate: 52
#
#
# ['Натальи', 'Наталья', 'Наталье', 'Натальи']
# similarity rate: 86
#
#
# ['Машенька', 'Риммы', 'Римма', 'Римма', 'Римма', 'Машенькой', 'Маша', 'Римма', 'Римма', 'Маша', 'Маша', 'Маше', 'Римма']
# similarity rate: 57
#
#
# ['Артём', 'Гиршпрунга', 'Артёма', 'Артём', 'Артема', 'Артёма', 'Артёму', 'Артём', 'Артёму', 'Артёма', 'Артёма', 'Артёма']
# similarity rate: 76
#
#
# ['Аня', 'Аня', 'Анна', 'Мо']
# similarity rate: 52
#
#
# ['Натальей', 'Наталья']
# similarity rate: 80
#
#
# ['Александре', 'Ирины', 'Ирина', 'Сашей', 'Александра', 'Александр', 'Саша', 'Саша', 'Саша', 'Саше', 'Саша', 'Саши', 'Саши', 'Саше', 'Александр', 'Саша', 'Саша', 'Ирина', 'Саши', 'Элле', 'Александра', 'Саша', 'Саша', 'Саши', 'Александру', 'Саша', 'Александру', 'Александра', 'Саши', 'Саши', 'Саша', 'Александра']
# similarity rate: 51
#
#
# ['Татьяне', 'Татьяне', 'Татьяне', 'Татьяне', 'Галей', 'Татьяне']
# similarity rate: 73
#
#
# ['БОГДАН', 'Богдан', 'Богдану', 'Богдан', 'Богдану', 'Трифиловых', 'Богдан']
# similarity rate: 53
#
#
# ['Дмитрий', 'Валерий', 'Валерий', 'Валерий', 'Валеру', 'Валерия', 'Валера', 'Валерия']
# similarity rate: 79
#
#
# ['Тимура', 'Тимура', 'Тимуре', 'Тимур', 'Тимур', 'Тимур', 'Тимка', 'Тимуркой', 'Тимуру', 'Тимур', 'Тимура', 'Тимуру']
# similarity rate: 85
#
#
# ['Матроскин', 'Матроскин', 'Матроскин', 'Матроскин', 'Котовский', 'Матроскин', 'Алексей', 'Котовский', 'Котовский']
# similarity rate: 67
#
#
# ['Насте', 'Насти', 'Настя', 'Насти', 'Настя', 'Настя', 'Насти', 'Анастасии', 'Насте']
# similarity rate: 75
#
#
# ['Юра', 'Юра', 'Юрин', 'Женя', 'Юрина', 'Женя', 'Юрин', 'Юра', 'Юре', 'Юры', 'Юры', 'Юре', 'Юра', 'Юра']
# similarity rate: 60
#
#
# ['Полине', 'Полины', 'Полина', 'Полина', 'Полина', 'Полина', 'Полине', 'Полине', 'Полину']
# similarity rate: 92
#
#
# ['Раиса', 'Раиса']
# similarity rate: 100
#
#
# ['Егора', 'Егор', 'Егор', 'Егор', 'Егора', 'Ксения', 'Егор', 'Ксения', 'Егору', 'Мария', 'Егора', 'Егор', 'Егор']
# similarity rate: 51
#
#
# ['Ильченко', 'Ильченко', 'Ильченко']
# similarity rate: 100
#
#
# ['Витя', 'Витя', 'Витя']
# similarity rate: 100
#
#
# ['Катюша', 'Катя', 'Катюша', 'Лепет', 'Катя', 'Катя', 'Катя', 'Катя', 'Кате', 'Кати', 'Илья', 'Илюше', 'Катиной']
# similarity rate: 54
#
#
# ['Соне', 'Соня', 'Соня', 'Соня', 'Сони', 'Соня', 'Соня', 'Соня', 'Сони', 'Матвей', 'Соня', 'Соня', 'Соня', 'Соне']
# similarity rate: 75
#
#
# ['Дарины', 'Арина', 'Дарина', 'Дарины', 'Дариной', 'Дарина', 'Дарина', 'Шишову', 'Дарине', 'Дарина', 'Дарине', 'Дарине', 'Арины', 'Дарина', 'Дарина', 'Дарина', 'Дарине', 'Дарины', 'Дарине']
# similarity rate: 74
#
#
# ['Луиза', 'Луиза', 'Луиза', 'Луиза', 'Луиза', 'Луиза', 'Луиза', 'Луизе', 'Луизы', 'Луизе', 'Луизе', 'Луиза', 'Луиза', 'Луиза', 'Луиза']
# similarity rate: 94
#
#
# ['Лере', 'Лера', 'Леры', 'Леры', 'Ванессе', 'Ванесса', 'Ванесса', 'Ванесса', 'Лере', 'Ванессе', 'Саше', 'Андрею']
# similarity rate: 60
#
#
# ['Миша', 'Миша']
# similarity rate: 100
#
#
# ['Екатерина', 'Екатерина', 'Катя']
# similarity rate: 66
#
#
# ['Альбой', 'Альба', 'Альба', 'Альба']
# similarity rate: 91
#
#
# ['Насти', 'ДАНИК', 'Настя', 'Насти', 'Настину', 'Насти', 'Настя', 'Настя', 'Насте', 'Калитенко']
# similarity rate: 65
#
#
# ['Юнии', 'Юния', 'Юния', 'Юния', 'Юния', 'Юния', 'Юнии', 'Юнии']
# similarity rate: 93
#
#
# ['Николь', 'Николь', 'Шатерниковы', 'Николь', 'Николь', 'Шатерниковы', 'Николь', 'Николь', 'Николь', 'Николь']
# similarity rate: 71
#
#
# ['Никите', 'Гентингтона', 'Гентингтона', 'Никита', 'Никита', 'Никита', 'Никите', 'Алевтина', 'Никиты', 'Никите']
# similarity rate: 60
#
#
# ['Саша', 'Саша', 'Саша', 'Саша']
# similarity rate: 100
#
#
# ['Федя', 'Феди', 'Федю', 'Федю', 'Федю', 'Феди', 'Феде', 'Феди', 'Феде']
# similarity rate: 81
#
#
# ['Владика', 'Владику', 'Фиранских', 'Владик', 'Светлана', 'Влад', 'Владик', 'Владик', 'Владика', 'Влад', 'Светлана', 'Владик', 'Влада', 'Владик', 'Владик', 'Владика', 'Фиранские', 'Владика', 'Владика', 'Владика']
# similarity rate: 63
#
#
# ['Дед', 'Дед', 'Дед', 'Снегурочка', 'Снегурочки']
# similarity rate: 76
#
#
# ['Даниил', 'Даниила', 'Анна', 'Даня', 'Даня', 'Даниила', 'Анна', 'Дане', 'Даня', 'Даня', 'Даня', 'Даня', 'Дани', 'Даню']
# similarity rate: 66
#
#
# ['Аня', 'Аня']
# similarity rate: 100
#
#
# ['Данила', 'Данила']
# similarity rate: 100
#
#
# ['Елена', 'Александра', 'Александру', 'Александр', 'Александра', 'Александру']
# similarity rate: 85
#
#
# ['А', 'А']
# similarity rate: 100
#
#
# ['Светы', 'Светы']
# similarity rate: 100
#
#
# ['ТУКТАРОВ', 'Саид', 'Саид', 'Саид', 'Саид', 'Саид', 'Саиду']
# similarity rate: 82
#
#
# ['Дмитриева', 'Светлане', 'Светлане']
# similarity rate: 62
#
#
# ['Алены', 'Татьяна', 'Алена', 'Алена', 'Алена', 'Алена', 'Алену', 'Татьяна', 'Алена', 'Джоконды', 'Марина', 'Алены', 'Алены', 'Алена', 'Алена', 'Татьяна', 'Алена', 'Алену', 'Алена', 'Алена', 'Алены', 'Аленой', 'Алены']
# similarity rate: 62
#
#
# ['Полине', 'Полина', 'Полина', 'Полины', 'Полины', 'Полина', 'Полину']
# similarity rate: 89
#
#
# ['Арина', 'Арина', 'Арину', 'Арине', 'Арины']
# similarity rate: 85
#
#
# ['Фаина', 'Миша', 'Миша', 'Миша', 'Миши', 'Мише', 'Мишеньки', 'Миши']
# similarity rate: 72
#
#
# ['Оськин', 'Оськин', 'Оси']
# similarity rate: 84
#
#
# ['Денис', 'Дениса', 'Денис', 'Денис', 'Денис', 'Денис']
# similarity rate: 96
#
#
# ['Геннадию', 'Геннадий', 'Геннадий', 'Герасимова', 'Геннадий', 'Геннадий']
# similarity rate: 75
#
#
# ['Варваа', 'Варвары', 'Варвара', 'Варя', 'Варвары', 'Варваре', 'Вари', 'Варюшке', 'Вари']
# similarity rate: 66
#
#
# ['Андрея', 'Андрей', 'Эмин', 'Эмин']
# similarity rate: 68
#
#
# ['Саша', 'Саша', 'Саша', 'Герасимовым', 'Сашу', 'Саша', 'Герасимовых', 'Герасимов', 'Саши']
# similarity rate: 54
#
#
# ['Виталик', 'Серёжи', 'Серёжу', 'Виталик', 'Серёжу', 'Серёжа', 'Серёжей', 'Екатерину', 'Серёже', 'Серёжа', 'Серёжи', 'Серёже', 'Серёжа', 'Серёжа', 'Серёжу', 'Серёжи', 'Серёжи', 'Серёжи', 'Серёже', 'Серёжа', 'Серёжа', 'Серёжиному', 'Серёжи', 'Серёжа', 'Серёжа', 'Серёжи', 'Серёжа']
# similarity rate: 72
#
#
# ['Тасе', 'Тася', 'Тасе', 'Диана', 'Тасе', 'Тася', 'Тася', 'Тася', 'Тася', 'Тасе', 'Тася', 'Тася', 'Тасина', 'Диана', 'Тасино', 'Диане', 'Тася']
# similarity rate: 64
#
#
# ['Дамей', 'Дамею', 'Дамей', 'Дамея']
# similarity rate: 80
#
#
# ['Маруся', 'Айкарди', 'Маша', 'Маша', 'Маша', 'Маша', 'Маша', 'Маруся']
# similarity rate: 70
#
#
# ['Анечка', 'Анютка']
# similarity rate: 67
#
#
# ['Юра', 'Юра', 'Юры', 'Юра', 'Юры', 'Владимира', 'Юра', 'Вова', 'Юра', 'Юра', 'Юра', 'Юра', 'Юра', 'Юры', 'Юра', 'Юры', 'Юре', 'Юре', 'Юры', 'Юры']
# similarity rate: 71
#
#
# ['Храмов', 'Жени', 'Женя', 'Жени', 'Жени', 'Женя', 'Женя', 'Женя', 'Жени', 'Женя', 'Жени', 'Жене']
# similarity rate: 75
#
#
# ['Данилы', 'Даниле', 'Даниле']
# similarity rate: 92
#
#
# ['Сорокин', 'Артем', 'Верднига', 'Артем', 'Артем', 'Артему', 'Артема']
# similarity rate: 54
#
#
# ['Луи', 'Луи', 'Луи']
# similarity rate: 100
#
#
# ['Дианой', 'Дебрянских', 'Дианы', 'Диане', 'Диана', 'Диана', 'Дианы', 'Дебрянских', 'Дианой', 'Диана']
# similarity rate: 57
#
#
# ['Михаилу', 'Михаил', 'Михаилу', 'Михаил', 'Михаила', 'Михаил', 'Михаил']
# similarity rate: 93
#
#
# ['Егор', 'Егору', 'Егор', 'Егор', 'Егор', 'Егор', 'Егор', 'Егор', 'Егор', 'Егор', 'Егор', 'Кати', 'Егор', 'Егора', 'Егору', 'Егору']
# similarity rate: 83
#
#
# ['Ольге', 'Ольга', 'Оля', 'Олечка', 'Олюша', 'Олечка', 'Оля', 'Оле', 'Ольга', 'Ольга', 'Ольге', 'Паша', 'Катя', 'Ольга', 'Ольга', 'Паше', 'Ольги', 'Ольги', 'Ольге', 'Ольги', 'Ольги', 'Ольга', 'Оля', 'Ольги', 'Оле']
# similarity rate: 58
#
#
# ['Дашей', 'Даша', 'Даша', 'Даши', 'Даша', 'Даше', 'Даша', 'Даша', 'Шамарина', 'Дашино', 'Даше']
# similarity rate: 70
#
#
# ['Эмильем', 'Эмиля', 'Оганян', 'Эмиль', 'Эмиля', 'Виктория', 'Эмилю', 'Эмиля', 'Эмиля', 'Эмиля', 'Эмилю']
# similarity rate: 57
#
#
# ['Кристина', 'Кристины', 'Кристины', 'Кристине', 'Кристина', 'Кристина', 'Кристина', 'Кристина', 'Кристина', 'Кристине', 'Кристина', 'Кристины', 'Коляска', 'Кристиной', 'Кристины']
# similarity rate: 83
#
#
# ['Сашеньки', 'Сашеньки', 'Саша', 'Сашеньки', 'Сашеньке']
# similarity rate: 72
#
#
# ['Лисенкову', 'Сережи', 'Сережа', 'Докшаниой', 'Сережа', 'Сереже', 'Сережа', 'Татьяна', 'Татьяны', 'Татьяна', 'Сережу', 'Сереже']
# similarity rate: 51
#
#
# ['Даня', 'Дани', 'Даня', 'Дани', 'Даня', 'Даня', 'Дани']
# similarity rate: 79
#
#
# ['Кристиной', 'Кристиной']
# similarity rate: 100
#
#
# ['Арман', 'Арману', 'Армана', 'Армана', 'Арману', 'Армана', 'Арману', 'Армана']
# similarity rate: 87
#
#
# ['Мария', 'Мария', 'Мария']
# similarity rate: 100
#
#
# ['Рената', 'Рената', 'Рената', 'Ренаты', 'Ренату', 'Рената', 'Ренаты', 'Рената', 'Ренаты', 'Ренате']
# similarity rate: 87
#
#
# ['Лысцев', 'Олегу', 'Олег', 'Олег', 'Олега', 'Евгений', 'Олегу', 'Олегу']
# similarity rate: 61
#
#
# ['Эллина', 'Эллина', 'Эллина', 'Наталья', 'Эллины', 'Эллины', 'Наталия', 'Эллины', 'Антоновых', 'Эллина', 'Эллина']
# similarity rate: 53
#
#
# ['Марина', 'Влада', 'Влад', 'Влада', 'Влада', 'Влад', 'Влад', 'Владом', 'Влада', 'Владик', 'Влада', 'Влада', 'Влада', 'Влада', 'Влада', 'Владислава']
# similarity rate: 85
#
#
# ['Матроскин', 'Матроскин', 'Матроскина', 'Матроскин', 'Матроскин', 'Матроскин']
# similarity rate: 98
#
#
# ['Матроскин', 'Матроскин', 'Матроскина', 'Матроскин', 'Матроскин', 'Матроскин']
# similarity rate: 98
#
#
# ['Маше', 'Кира', 'Кира', 'Кира', 'Кира', 'Кире']
# similarity rate: 80
#
#
# ['Даниила', 'Данииле', 'Данилка', 'Данилка', 'Данилу', 'Данилка', 'Оксана', 'Даниила', 'Даниила', 'Данилка']
# similarity rate: 77
#
#
# ['Матвей', 'Матвею', 'Матвею', 'Матвей', 'Матвея', 'Матвея', 'Матвею', 'Матвея']
# similarity rate: 88
#
#
# ['Тасе', 'Тасиной', 'Тасе', 'Тасе', 'Тасе', 'Тася', 'Тася', 'Тася', 'Тася', 'Тасе']
# similarity rate: 84
#
#
# ['Мирослава', 'Мирослава', 'Веста', 'Мирославы']
# similarity rate: 53
#
#
# ['Саши', 'Александры', 'Александра', 'Александра', 'Александра']
# similarity rate: 76
#
#
# ['Вики', 'Вика', 'Вика', 'Вика', 'Вика', 'Вика', 'Вику', 'Виктории']
# similarity rate: 86
#
#
# ['Деду', 'Деда']
# similarity rate: 75
#
#
# ['Эдуард', 'Эдуард', 'Эдуарда', 'Кравченко', 'Даня', 'Даня', 'Гросса', 'Дане', 'Гудкова', 'Костя', 'Костя', 'Косте', 'Надежда', 'Эдуарду', 'Эдуард', 'Эдуарда']
# similarity rate: 55
#
#
# ['Евгения', 'Евгения', 'Евгении', 'Николай', 'Коля', 'Коля', 'Коле', 'Александр', 'Александр', 'Александр', 'Лилиана', 'Лилиана', 'Анатолий', 'Анатолий', 'Анатолий', 'Анатолий', 'Юлия', 'Юлии', 'Юлии', 'Юлия', 'Наталья', 'Наталья', 'Наталья', 'Наталья', 'Дмитрий', 'Дмитрий', 'Дмитрий', 'Зоя', 'Зоя', 'Зоя', 'Ирина', 'Ирина', 'Коляску', 'Ирина', 'Сергей', 'Сергей', 'Сергей', 'Сергей', 'Сергей', 'Сергея', 'Наталия', 'Наталия', 'Наталия']
# similarity rate: 70
#
#
# ['Коля', 'Колино', 'Ульриха', 'Колиным', 'Коля', 'Коля', 'Коли', 'Колина', 'Колю']
# similarity rate: 61
#
#
# ['Грише', 'Грише', 'Гриша', 'Гриши', 'Гришу', 'Гриши', 'Грише', 'Гриша', 'Грише', 'Грише', 'Нексавара', 'Гришу']
# similarity rate: 72
#
#
# ['Кирилл', 'Кирилла', 'Кирилл', 'Кирилл', 'Кирилл', 'Кирилла', 'Кирилл', 'Кирилл', 'Даня', 'Кирилл', 'Кирилл', 'Кирилла', 'Папа', 'Кирилла', 'Кирилл']
# similarity rate: 71
#
#
# ['Мишу', 'Миши', 'Миши', 'Миша', 'Мише']
# similarity rate: 81
#
#
# ['Грише', 'Грише', 'Гриша', 'Григорий', 'Гриши', 'Гриша', 'Гришы', 'Гриша', 'Гриши', 'Гриша']
# similarity rate: 76
#
#
# ['Кузнецовым', 'Рома', 'Ромочки', 'Роман', 'Апгар', 'Роману', 'Кузнецовых', 'Ромы', 'Роме', 'Рома', 'Романа', 'Роман', 'Ромы', 'Рома', 'Ромы', 'Роме']
# similarity rate: 55
#
#
# ['Мамедовой', 'Сабина', 'Сабины', 'Сабину', 'Сабина', 'Сабины']
# similarity rate: 69
#
#
# ['Назар', 'Наговицыной', 'Татьяны', 'Назар', 'Татьяну', 'Татьяны', 'Назара', 'Назаром', 'Татьяну', 'Татьяне', 'Татьяне', 'Назара', 'Назару', 'Назар', 'Назарке', 'Назару']
# similarity rate: 54
#
#
# ['Жени', 'Жени', 'Ольга', 'Жени', 'Жене', 'Жене']
# similarity rate: 55
#
#
# ['Димы', 'Наталья', 'Дима', 'Дима', 'Дима', 'Диме']
# similarity rate: 59
#
#
# ['Елена', 'Александра', 'Елена', 'Елена', 'Елена', 'Елена', 'Александрой']
# similarity rate: 72
#
#
# ['Кати', 'Катя', 'Катюша', 'Катя', 'Кате', 'Катюши', 'Кате', 'Кати', 'Кати', 'Катюши', 'Катюше', 'Кате']
# similarity rate: 73
#
#
# ['Матвею', 'Алиночки', 'Алининой', 'Юли', 'Алины', 'Алина', 'Алины']
# similarity rate: 51
#
#
# ['Даша', 'Даша', 'Даша', 'Даша', 'Даша', 'Ираида', 'Ираиды', 'Ушера', 'Ираиде', 'Ираиде', 'Маша', 'Оксана']
# similarity rate: 69
#
#
# ['Максим', 'Максимки', 'Максимка', 'Ольги', 'Маша', 'Машенька', 'Машей', 'Морфана', 'Вова', 'Вове', 'Вовочка', 'Вове', 'Вовочке', 'Вовы', 'Дима', 'Диму', 'Дима', 'Дима', 'Дима', 'Диму', 'Диме', 'Димы', 'Татьяна']
# similarity rate: 58
#
#
# ['Арину', 'Арине', 'Арина', 'Арины', 'Катетер', 'Ариша', 'Арины', 'Арине', 'Ариши', 'Арине']
# similarity rate: 59
#
#
# ['София', 'Софии', 'Софии', 'Софии', 'Софии']
# similarity rate: 95
#
#
# ['Алена', 'Владимир', 'Владимира', 'Владимир', 'Михаил']
# similarity rate: 58
#
#
# ['Аль', 'Лахим', 'Лахим', 'Лахима', 'Лахим', 'Лахима', 'Лахим', 'Лахиму', 'Лахим', 'Лахиму']
# similarity rate: 82
#
#
# ['Екатерина', 'Стаси', 'Шамарина', 'Стася', 'Стасю', 'Никиту', 'Стаси', 'Стаси', 'Стасе', 'Екатерины', 'Стаси', 'Стасе', 'Стася', 'Стасе', 'Стасюша', 'Стаси']
# similarity rate: 54
#
#
# ['Владу', 'Дюшенна', 'Влад', 'Влад', 'Влад', 'Влада', 'Влад', 'Владу', 'Влада', 'Владу']
# similarity rate: 74
#
#
# ['Мирославе', 'Мирослава', 'Мира', 'Мира', 'Мирославе', 'Птоз', 'Миры', 'Мирославе', 'Миры', 'Мирославе']
# similarity rate: 52
#
#
# ['Скандеру', 'Скандер', 'Скандера', 'Скандера']
# similarity rate: 95
#
#
# ['Маша', 'Марии', 'Маши', 'Маша', 'Машенька', 'Маша', 'Маши']
# similarity rate: 66
#
#
# ['Артем', 'Артем', 'Артем', 'Артемки', 'Артема', 'Артемом', 'Артема', 'Артем', 'Артему', 'Артема', 'Артем']
# similarity rate: 87
#
#
# ['Руфине', 'Руфины', 'Руфине', 'Руфиной', 'Руфина', 'Руфины', 'Руфине']
# similarity rate: 81
#
#
# ['Сергея', 'Сергей', 'Коляска', 'Сергей', 'Сергею', 'Сергею', 'Сергея', 'Сергей', 'Сергей', 'Сергей', 'Сергея', 'Сергею']
# similarity rate: 73
#
#
# ['Сашей', 'Саша', 'Саша', 'Саша', 'Саша', 'Саше', 'Илья', 'Саше', 'Саше']
# similarity rate: 68
#
#
# ['Амалией', 'Амалия', 'Амалия', 'Амалия']
# similarity rate: 92
#
#
# ['Асланы', 'Аслане', 'Асланой', 'Аслана', 'Аслана', 'Асланы', 'Асланой', 'Асланы']
# similarity rate: 82
#
#
# ['Лучик', 'Ирочка', 'Егор', 'Егору', 'Егор', 'Егора', 'Егор', 'Егору', 'Егора', 'Егора', 'Егору', 'Егору', 'Ирочка', 'Егор', 'Ирочка', 'Егора', 'Ирочка', 'Егора', 'Ира', 'Егор', 'Егор']
# similarity rate: 60
#
#
# ['Булата', 'Булату', 'Булата', 'Булат', 'Булату', 'Булат', 'Булата', 'Булат', 'Булату', 'Булату']
# similarity rate: 90
#
#
# ['Тэи', 'Тэи', 'Ване', 'Ваня', 'Ваня', 'Вани', 'Вани', 'Ваня', 'Ваня', 'Ваня', 'Ваня', 'Ваню', 'Вани', 'Вани']
# similarity rate: 83
#
#
# ['Хайрулин', 'Ильдар', 'Ильдар', 'Ильдар', 'Ильдара']
# similarity rate: 80
#
#
# ['Андрей', 'Андрея', 'Андрюше', 'Андрей', 'Андрей', 'Андрею', 'Андрею', 'Шамарина', 'Андрею', 'Андрею', 'Андрею']
# similarity rate: 75
#
#
# ['Саше', 'Саша', 'Саша', 'Саша', 'Саши']
# similarity rate: 88
#
#
# ['Неупокоева', 'Пушкова', 'Настей', 'Настей', 'Настя', 'Настя', 'Настя']
# similarity rate: 74
#
#
# ['Аня', 'Аня', 'Аня']
# similarity rate: 100
#
#
# ['Светланы', 'Аня', 'Ане', 'Аня', 'Аня', 'Аня', 'Ходжкина', 'Вероника', 'Аня', 'Аня', 'Вероники', 'Аня', 'Аню', 'Аня', 'Аня', 'Аня', 'Аня', 'Аня', 'Ани', 'Вероника', 'Ани', 'Ани', 'Аня', 'Вероникой', 'Аню', 'Аня', 'Аня', 'Ане', 'Мария']
# similarity rate: 60
#
#
# ['ЛЕНА', 'Ходжкина', 'Лена', 'Лене', 'Лена', 'Лена', 'Лены']
# similarity rate: 60
#
#
# ['Л', 'Давид', 'Самвел', 'Давид', 'Давида', 'Давида', 'Давид', 'Давида', 'Давид', 'Малаховой', 'Давида']
# similarity rate: 59
#
#
# ['Виктория', 'Гия', 'Гия']
# similarity rate: 68
#
#
# ['Оливер', 'Мария', 'Марии', 'Марии', 'Малаховой', 'Мария', 'Баграт', 'Баграта', 'Баграта', 'Мая', 'Багратик', 'Баграт', 'Багратику', 'Марии']
# similarity rate: 56
#
#
# ['Рома', 'Рома']
# similarity rate: 100
#
#
# ['Римы', 'Баталовой', 'Мелиса', 'Мелиса', 'Мелиса', 'Юлия', 'Юлия']
# similarity rate: 59
#
#
# ['Журавлёвых', 'Ангелина', 'Ангелина', 'Ангелина', 'Ангелине', 'Ангелины', 'Ангелине']
# similarity rate: 79
#
#
# ['Матроскин', 'Матроскин', 'Матроскин', 'Матроскин', 'Матроскин']
# similarity rate: 100
#
#
# ['Альбина', 'Аля', 'Альбины', 'Альбина', 'Альбины', 'Альбины', 'Альбины', 'Альбина', 'Альбина', 'Альбина', 'Альбина', 'Альбина', 'Альбине']
# similarity rate: 85
#
#
# ['Геннадий', 'Геннадия', 'Геннадии', 'Сергей', 'Геннадий', 'Геннадий', 'Геннадий', 'Геннадию']
# similarity rate: 72
#
#
# ['Артем', 'Артема', 'Наталья', 'Артем', 'Артема', 'Артем']
# similarity rate: 64
#
#
# ['Астрей', 'Ларисе', 'Ларисе', 'Лариса', 'Лариса']
# similarity rate: 79
#
#
# ['Деду', 'Деда']
# similarity rate: 75
#
#
# ['Инна', 'Инна', 'Инна', 'Инне', 'Инна', 'Инне']
# similarity rate: 85
#
#
# ['Милена', 'Милена', 'Тания', 'Милены', 'Анна', 'Милена', 'Милена', 'Милене', 'Милене', 'Милены', 'Милены']
# similarity rate: 66
#
#
# ['Яна', 'Яну', 'Ян', 'Яна', 'Яна', 'Яна', 'Яну', 'Ян', 'Яна', 'Яну', 'Яна']
# similarity rate: 79
#
#
# ['Саша', 'Саша', 'Саша', 'Саши', 'Саша', 'Саша', 'Саше']
# similarity rate: 88
#
#
# ['Ангелинки', 'Ангелина', 'Ангелина']
# similarity rate: 91
#
#
# ['Куприяновой', 'Екатерины', 'Алины', 'Екатерины', 'Алину', 'Алиночки', 'Алинушка', 'Алина', 'Алины', 'Алины', 'Алина', 'Екатерина', 'Куприяновой']
# similarity rate: 57
#
#
# ['ДЕТЯМ', 'РОДИТЕЛЯМ']
# similarity rate: 57
#
#
# ['Димы', 'Дима', 'Дима', 'Димы', 'Димы']
# similarity rate: 88
#
#
# ['Сережа', 'Сережа', 'Сереже', 'Лешу', 'Сеража', 'Сереже', 'Сережа', 'Китовых']
# similarity rate: 53
#
#
# ['Гульнара', 'Гульнара', 'Гульнары', 'Гульнару', 'Томас', 'Гульнаре', 'Гульнара', 'Гульнары', 'Гульнары', 'Анаида', 'Гульнару', 'Томас', 'Гульнаре', 'Гульнара']
# similarity rate: 58
#
#
# ['Станислава', 'Стас', 'Станислава', 'Стаса', 'Станиславу', 'Стас', 'Стаса', 'Стаса', 'Стас', 'Стаса', 'Станислав', 'Стаса', 'Стас']
# similarity rate: 75
#
#
# ['Семёнов', 'Семёна', 'Семена', 'Семена', 'Семы', 'Семена', 'Семена']
# similarity rate: 80
#
#
# ['Парез', 'Комиссаровой', 'ПАРАЛИЧ', 'Натальи', 'Наталье', 'Наталью', 'Светлана', 'Вари', 'Варя', 'Варе', 'Новикова', 'Варя', 'Варя', 'Вари', 'Варя', 'Вари', 'Варя', 'Варе']
# similarity rate: 53
#
#
# ['Вани', 'Ваню', 'Ваня', 'Вани', 'Ваню', 'Ваня', 'Ваню', 'Ваню', 'Ваня', 'Ваня', 'Вани', 'Ваню', 'Ваней', 'Ваня', 'Ваня', 'Ваню', 'Ваниной', 'Ване', 'Вани']
# similarity rate: 76
#
#
# ['Аня', 'Мариной', 'Вани', 'Ваня', 'Ваня', 'Ване', 'Ваня', 'Вани', 'Ваня', 'Ваня', 'Настя', 'Настя', 'Ваня', 'Олей', 'Оля', 'Вани', 'Ваня', 'Аня']
# similarity rate: 59
#
#
# ['Ваней', 'Ваня', 'Ваня', 'Дарья', 'Ване', 'Ваня', 'Буковых']
# similarity rate: 51
#
#
# ['Артёмка', 'Артёмке', 'Артёмкой', 'Артёмку', 'Тема', 'Темы', 'Артёмке', 'Артёмкиной', 'Артёмкиной', 'Атрёмке']
# similarity rate: 65
#
#
# ['Эллина', 'Эллина', 'Эллине', 'Эллине', 'Эллины', 'Юлия', 'Эллиночку']
# similarity rate: 73
#
#
# ['Ярослава', 'Ярослав', 'Ярославе', 'Ярослав', 'Ярослав', 'Ярославв', 'Марина', 'Ярослава', 'Ярославу']
# similarity rate: 77
#
#
# ['Кратковой', 'Ванюша', 'Ваня', 'Ванечка', 'Марина', 'Ване', 'Ване']
# similarity rate: 52
#
#
# ['Светланы', 'Светлана', 'Светланы']
# similarity rate: 88
#
#
# ['Волкомурова', 'Михайленко', 'Тимофея', 'Тимофея', 'Тимоши', 'Михайленко', 'Тимофея', 'Тимофей', 'Тимоша', 'Тимофея', 'Тимофей', 'Тимошу', 'Тимофею']
# similarity rate: 57
#
#
# ['Латыповой', 'Луиза', 'Луизы', 'Луиза', 'Луизы', 'Луизе']
# similarity rate: 70
#
#
# ['Кирилл', 'Шередарь', 'Лешей', 'Аня', 'Ирина', 'Антона', 'Антона', 'Антон', 'Антоша', 'Антоном', 'Антон', 'Aнтон']
# similarity rate: 54
#
#
# ['Иван', 'Иван']
# similarity rate: 100
#
#
# ['Деда', 'Деду']
# similarity rate: 75
#
#
# ['Мария', 'Максим']
# similarity rate: 55
#
#
# ['Дмитриевой', 'Кристина', 'Кристина', 'Кристины', 'Кристина', 'Кристина', 'Кристину', 'Кристина', 'Кристины', 'Кристине', 'Кристины', 'Кристины', 'Кристина', 'Кристины', 'Кристине']
# similarity rate: 86
#
#
# ['Францева', 'Ирине', 'Ходжкина', 'Ирина', 'Ирине', 'Ириной', 'Ирина', 'Рината', 'Рауф', 'Ирине', 'Ирины', 'Ринате']
# similarity rate: 51
#
#
# ['Юлию', 'Юлия', 'Юлия', 'Юлия', 'Юлии']
# similarity rate: 88
#
#
# ['Сашеньки', 'Сашеньки', 'Саша', 'Сашеньки']
# similarity rate: 67
#
#
# ['Асланы', 'Асланы', 'Аслана', 'Аслана', 'Асланы', 'Аслана']
# similarity rate: 90
#
#
# ['Натальей', 'Наталья']
# similarity rate: 80
#
#
# ['Лизунов', 'Лизунов', 'Лизунов', 'Лизунов']
# similarity rate: 100
#
#
# ['Алиночка', 'Алиночке', 'Алиночка', 'Алина', 'Алиночка', 'Алиночка', 'Алине', 'Алине', 'Алины', 'Алина']
# similarity rate: 84
#
#
# ['Леша', 'Алексей', 'Лешенька', 'Леша', 'Леша', 'Алеша', 'Леши']
# similarity rate: 54
#
#
# ['Максима', 'Бодилевская', 'Максику', 'Максим', 'Максим', 'Максима', 'Максима', 'Максим', 'Максима', 'Максима', 'Слава', 'Максима', 'Максим', 'Слава']
# similarity rate: 66
#
#
# ['Дамира', 'Дамир', 'Дамир', 'Дамирчика', 'Дамиру', 'Дамиру', 'Хакимова', 'Дамиру', 'Дамир', 'Дамир', 'Дамир', 'Дамирчика', 'Дамир', 'Дамирка', 'Дамир', 'Дамир', 'Дамиру', 'Дамир', 'Дамиру', 'Дамир', 'Дамир', 'Дамира', 'Дамир', 'Дамир', 'Дамира', 'Дамиру', 'Дамира', 'Хакимовы', 'Махмут']
# similarity rate: 80
#
#
# ['Николь', 'Николь', 'Николь', 'Николь', 'Николь', 'Николь', 'Николь', 'Николь', 'Николь', 'Николь', 'Николь', 'Николь', 'Николь']
# similarity rate: 100
#
#
# ['Аня', 'Аня']
# similarity rate: 100
#
#
# ['Денис', 'Айлин', 'Айлин', 'Абдрасуловой', 'Айлин', 'Айлин', 'Айлин', 'Айлин', 'Айлин', 'Айлин', 'Малика']
# similarity rate: 70
#
#
# ['Лене', 'Елена', 'Лены', 'Лена', 'Лене', 'Лена', 'Лене', 'Елена', 'Леночке', 'Леночке']
# similarity rate: 63
#
#
# ['Саши', 'Саши', 'Сашеньки', 'Саши', 'Саши', 'Сашеньке', 'Саши', 'Фельденкрайза', 'Сандакову']
# similarity rate: 58
#
#
# ['Роман', 'Роман', 'Роман']
# similarity rate: 100
#
#
# ['Сабрины', 'Сабрина', 'Сабрина', 'Сабрина', 'Сабрине', 'Сабриночке']
# similarity rate: 91
#
#
# ['Леве', 'Льву', 'Леве', 'Лев', 'Апгар', 'Левушка', 'Лева', 'Лева', 'Леве', 'Лева', 'Левы', 'Ли']
# similarity rate: 58
#
#
# ['Дениса', 'Денис']
# similarity rate: 91
#
#
# ['Александром', 'Александра', 'Саша', 'Саша', 'Юра', 'Иры', 'Чернецкий', 'Александр', 'Александр', 'Александр', 'Александр', 'Сашка', 'Янка', 'Коча', 'Александр', 'Александр', 'Александр', 'Александр', 'Александр', 'Сашка', 'Клим', 'Александр', 'Александр', 'Чернецкий', 'Клим', 'Александр', 'Александр', 'Александр', 'Александр', 'Александр', 'Александр', 'Александр', 'А', 'Александр', 'Пётр', 'Александр', 'Черненцкий', 'Сланч', 'Александр', 'Чернецкий', 'Кожекин', 'Чернецкий', 'Кожекин', 'Чернецкий', 'Чиж', 'Александр', 'Александр', 'Александр', 'Кати', 'Чернецкий', 'Чиж', 'Блока', 'Че', 'Чи', 'Блока', 'Александр', 'Александр', 'Чернецкий', 'Михайленко', 'Чернецкий', 'Акимов', 'Александр', 'А', 'Александр', 'Павелецкой', 'Чернецкий', 'Александр', 'Александр', 'Александр', 'Александр', 'Чернецкий', 'Махов', 'Александр', 'Виктором', 'Александр', 'Александр', 'Александр', 'Александр', 'Шевчука', 'Чижа', 'Чернецкого', 'Александр', 'Александр', 'Владимира', 'Александр', 'Чижа', 'Чернецкого', 'Чернецкого', 'Чижа', 'Чернецкого', 'Чижа', 'Чернецкого', 'Чижа', 'Чернецкого', 'Чижа', 'Чернецкого', 'Чернецкого', 'Чернецкого', 'Чернецкого', 'Чижа', 'Чернецкого', 'Чижа', 'Чернецкого', 'Чернецкого', 'Чернецкого', 'Чернецкого', 'Чернецкого', 'Чернецкого', 'Че', 'Чи', 'Блока', 'Чернецкого', 'Чернецкого', 'Чернецкого', 'Виктором', 'А', 'Чиж', 'Чернецкий', 'Чернецкого', 'Высоцкого', 'Чернецкого', 'Чернецкого', 'Чернецкий', 'Акимов', 'Чернецкого', 'Чернецкого', 'Чернецкий', 'Чернецкого', 'Савтографом', 'Чернецкого', 'Чернецкого', 'Чернецкого', 'Чернецкого', 'Иваном', 'Чернецкого', 'Чернецкого', 'Александра', 'Михаила', 'Чернецкого', 'Чернецкого', 'Чернецкого', 'Чернецкого', 'Савтографом', 'Чернецкого', 'Чернецкого', 'Чернецкого', 'Чернецкого', 'Чернецкого', 'Чернецкого', 'Чернецкого', 'Чернецкого', 'Чернецкого']
# similarity rate: 52
#
#
# ['Женя', 'Эмили', 'Женя', 'Женя', 'Жени', 'Жени', 'Женя', 'Женя', 'Жене', 'Женю', 'Жененой', 'Жени', 'Жене']
# similarity rate: 65
#
#
# ['Матвея', 'Матвеем', 'Матвейки', 'Матвей', 'Матвей', 'Матвей', 'Матвея', 'Матвея', 'Владиславу', 'Алевтине', 'Алюшу']
# similarity rate: 69
#
#
# ['Рома', 'Рома', 'Ромы', 'Роме', 'Рому']
# similarity rate: 81
#
#
# ['Терри', 'Терри', 'Михаилом', 'Михаилу', 'Чулпан']
# similarity rate: 52
#
#
# ['Диану', 'Диана', 'Кирилл', 'Диана', 'Ольга', 'Дианы', 'Дианочку', 'Диана', 'Диана', 'Диане', 'Дианочке']
# similarity rate: 54
#
#
# ['Морозом', 'Снегурочкой', 'Деда', 'Дедом', 'Дед', 'Деда']
# similarity rate: 55
#
#
# ['Никита', 'Никиты', 'Никиты', 'Никиты', 'Никита', 'Никитке', 'Никите', 'Никиты', 'Никиты', 'Никите', 'Никиты', 'Никиты']
# similarity rate: 89
#
#
# ['Родиона', 'Родиона', 'Родиона', 'Родиону']
# similarity rate: 95
#
#
# ['Василий', 'Василий', 'Василия', 'Василий', 'Василия', 'Василий', 'Василия', 'Василий', 'Василий', 'Василия', 'Василий', 'Василий', 'Василия', 'Василия', 'Василия', 'Василий', 'Василия', 'Валерий', 'Любовь']
# similarity rate: 83
#
#
# ['Арсений', 'Арсений', 'Арсению', 'Арсений', 'Арсюша']
# similarity rate: 80
#
#
# ['Люшера', 'Люшера']
# similarity rate: 100
#
#
# ['Аслана', 'Аслане', 'Асланой', 'Аслана', 'Аслана', 'Асланы', 'Асланой', 'Асланы']
# similarity rate: 82
#
#
# ['Костю', 'Юлий', 'Костя', 'Кости', 'Костю', 'Костю', 'Косте', 'Костю', 'Костя', 'Костя', 'Костя', 'Косте', 'Костю']
# similarity rate: 72
#
#
# ['Юле', 'Юля', 'Юля', 'Юли', 'Юли']
# similarity rate: 84
#
#
# ['Лизе', 'Лиза', 'Лиза', 'Лизе', 'Верника', 'Лиза', 'Лиза', 'Лиза', 'Лизу', 'Лизу', 'Лизу', 'Лизы', 'Лизе', 'Лизы', 'Лизы', 'Лизы', 'Верника', 'Диме', 'Дима', 'Дима', 'Дима', 'Дед', 'Диму', 'Влада', 'Лиза', 'Лизы']
# similarity rate: 67
#
#
# ['Сашеньке', 'Сашина', 'Саша', 'Саше', 'Саше', 'Сашины', 'Саше']
# similarity rate: 72
#
#
# ['Феликса', 'Феликс', 'Феликс', 'Феликса', 'Феликса', 'Феликусу']
# similarity rate: 93
#
#
# ['Ольга', 'Ольга', 'Екатерина']
# similarity rate: 57
#
#
# ['Бронских', 'Валерии', 'Валерии', 'Валерия', 'Романова', 'Валерия', 'Валерии']
# similarity rate: 54
#
#
# ['Саше', 'Саши', 'Никиты', 'Никиты', 'Никита', 'Никиты', 'Никита', 'Никита', 'Никита', 'Никиты', 'Никиты', 'Никиты', 'Никите', 'Никиту', 'Никиты', 'Никите']
# similarity rate: 84
#
#
# ['Валерия', 'Кирюша', 'Гридасова', 'Кирилла', 'Вусала', 'Вячеславу', 'Вячеслава', 'Славика', 'Слава', 'Славы', 'Славик', 'Славик', 'Славику', 'Славы', 'Елена', 'Славы', 'Слава', 'Славика']
# similarity rate: 61
#
#
# ['Владислав', 'Влад', 'Владька', 'Влада']
# similarity rate: 73
#
#
# ['Андрея', 'Аня', 'Андрей', 'Андрей', 'Анне', 'Анна', 'Андрея', 'Андрея']
# similarity rate: 69
#
#
# ['Игоря', 'Игорю', 'Игорем', 'Мельниковой', 'Мельниковой', 'Мельниковой']
# similarity rate: 73
#
#
# ['Илюша', 'Илья', 'Илья', 'Илюша', 'Мария', 'Ильи', 'Ильи', 'Илюше']
# similarity rate: 53
#
#
# ['Дуся', 'Дуся']
# similarity rate: 100
#
#
# ['Михаила', 'Михаил', 'Трисоне', 'Трисоне']
# similarity rate: 69
#
#
# ['Насте', 'Настя', 'Настя', 'Ванечкой', 'Феде', 'Феди', 'Федя', 'Фединой', 'Вике', 'Вика', 'Вики', 'Вика', 'Вика', 'Вика', 'Вика', 'Насти', 'Феди', 'Федя', 'Настя', 'Настя', 'Насте', 'Феде', 'Вике', 'Вики', 'Насти', 'Феди', 'Насти', 'Анна', 'Павловой']
# similarity rate: 54
#
#
# ['Сергею', 'Сергею', 'Сергей', 'Сергея', 'Сергей', 'Сергея', 'Сергей', 'Сергею', 'Сергею', 'Сергей']
# similarity rate: 87
#
#
# ['Инвакон', 'Даша', 'Даше', 'Даши', 'Даша', 'Дашина', 'Даша', 'Дашиных', 'Дашин', 'Юпитер', 'Даше', 'Дашины', 'Даши']
# similarity rate: 60
#
#
# ['Саше', 'Саша', 'Сашке', 'Саше', 'Саша', 'Саша', 'Саши', 'Саши', 'Саши', 'Саша', 'Саше', 'Вами', 'Саши', 'Саша']
# similarity rate: 75
#
#
# ['Нептуну', 'Нептун']
# similarity rate: 92
#
#
# ['Лукия', 'Лукия', 'Лукия', 'Лукии', 'Лукия', 'Лукия', 'Лукие', 'Лукии', 'Заболотникова', 'Лукию']
# similarity rate: 71
#
#
# ['Аня', 'Ани', 'Аня', 'Аня', 'Аниной', 'Анастасии', 'Ане', 'Аня', 'Ани']
# similarity rate: 61
#
#
# ['Наставник', 'Ребенок', 'Волонтер', 'Эрика', 'Эрик', 'Эрик', 'Эрик', 'Эрик', 'Эрик', 'Эрика']
# similarity rate: 70
#
#
# ['Камиль', 'Камиль', 'Камиля', 'Камиль', 'Камиль', 'Камиль', 'Камиль', 'Лекотеки']
# similarity rate: 83
#
#
# ['Оля', 'Олин', 'Оля', 'Оля', 'Наталья']
# similarity rate: 64
#
#
# ['Даше', 'Даша', 'Даша', 'Даше', 'Даша', 'Даше']
# similarity rate: 80
#
#
# ['Оксана', 'Оксане', 'Оксана', 'Оксаны', 'Оксанин', 'Оксана', 'Оксана', 'Оксану', 'Оксана', 'Оксаниного', 'Оксаниных', 'Оксанин', 'Оксанину', 'Тем', 'Оксана', 'Оксану', 'Оксаны', 'Оксану', 'Оксана', 'Оксаны']
# similarity rate: 74
#
#
# ['Мамин', 'Миша', 'Миша', 'Миши', 'Мише', 'Миша']
# similarity rate: 74
#
#
# ['Натальи', 'Наталья']
# similarity rate: 86
#
#
# ['Света', 'Светы', 'Светы', 'Света', 'ВАШ']
# similarity rate: 65
#
#
# ['Алисой', 'Алиса', 'Алисы', 'Эркан', 'Алисы', 'Алисе', 'Алиса']
# similarity rate: 52
#
#
# ['Даши', 'Даша', 'Даши', 'Даши']
# similarity rate: 83
#
#
# ['Ваней', 'Ване', 'Вани', 'Ваня', 'Ваня', 'Ваня', 'Гутмманн', 'Ване', 'Вани', 'Ваня', 'Ване']
# similarity rate: 73
#
#
# ['Павел', 'Павлу', 'Павел', 'Павел', 'Павел', 'Павла']
# similarity rate: 88
#
#
# ['Андрея', 'Андрея', 'Андрея', 'Андрей', 'Эмин', 'Андреем']
# similarity rate: 64
#
#
# ['Саша', 'Саша', 'Саша', 'Саша']
# similarity rate: 100
#
#
# ['Диму', 'Дима', 'Димы', 'Димы', 'Д', 'Димы', 'Димы', 'Диме', 'Димы', 'Жилиных', 'Диминых', 'Дима', 'Димы', 'Димы', 'Диме', 'Дима']
# similarity rate: 71
#
#
# ['Федоровых', 'Федоровых', 'Федоровых', 'Даймонд']
# similarity rate: 71
#
#
# ['Уютки', 'Уютки']
# similarity rate: 100
#
#
# ['Кирилл', 'Кирюша', 'Кирилла', 'Кирюши', 'Кирюше', 'Кирюши', 'Кириллу', 'Кирилл', 'Кирилл', 'Кирилла', 'Кирилла', 'Кириллу', 'Кирилл', 'Милена', 'Кириллом', 'Кириллу', 'Кирюши']
# similarity rate: 73
#
#
# ['Алене', 'Алены', 'Алены', 'Алена', 'Алена', 'Алена', 'Алену', 'Алёнка', 'Алене', 'Садик', 'Ермалюки', 'Аленой', 'Алена', 'Алена', 'Алены', 'Алёны']
# similarity rate: 69
#
#
# ['Александр', 'Алину', 'Алина', 'Алине', 'Влада', 'Влад', 'Влад', 'Маргарита']
# similarity rate: 61
#
#
# ['Морозовой', 'Морозова']
# similarity rate: 82
#
#
# ['Сергей', 'Светлана', 'Света', 'Света', 'Светы', 'Наталья']
# similarity rate: 61
#
#
# ['Саше', 'Сашина', 'Саши', 'Саша', 'Саша', 'Саше', 'Саше', 'Баха', 'Баха', 'Саши', 'Александра', 'Саше']
# similarity rate: 61
#
#
# ['Ксения', 'Ксения', 'Дарлей', 'Ксении', 'Ксении', 'Ксения', 'Дарлея', 'Ксении', 'Ксения', 'Ксении', 'Ксении']
# similarity rate: 63
#
#
# ['Чингис', 'Чингиса', 'Резеда', 'Чингис', 'Чингису', 'Свинка', 'Чингис', 'Чингис', 'Чингису', 'Чингиса', 'Войта', 'Бобат', 'Чингису', 'Чингиса', 'Чингису']
# similarity rate: 55
#
#
# ['Дима', 'Дима', 'Дима', 'Надежды', 'Диму', 'Дима', 'Дима', 'Диме']
# similarity rate: 67
#
#
# ['Дмитрия', 'Дмитрий', 'Дмитрий', 'Дима', 'Дима', 'Димы', 'Дима', 'Дима', 'Димы']
# similarity rate: 81
#
#
# ['Маргарита', 'Маргарита', 'Маргарита', 'Маргарита', 'Маргарита', 'Маргарите', 'Маргарита', 'Маргарите']
# similarity rate: 95
#
#
# ['Даше', 'Дашеньки', 'Даша', 'Даша', 'Даша', 'Даша', 'Дашенька', 'Даши', 'Даша', 'Даша', 'Даша', 'Даши']
# similarity rate: 80
#
#
# ['Орехов', 'Томатис', 'Томатис']
# similarity rate: 58
#
#
# ['Ластик', 'Ластик', 'Штрих']
# similarity rate: 68
#
#
# ['Ксюше', 'Ксюша', 'Ксения', 'Ксюшу', 'Ксюша', 'Ксюши', 'Ксюша', 'Ксюшей', 'Ксюшей', 'Ксюши', 'Ксюши', 'Ксюша', 'Ксюша']
# similarity rate: 76
#
#
# ['Ушницких', 'Светлана', 'Михаил', 'Ивановых', 'Ивановых', 'Мария', 'Мария', 'Мария', 'Мария', 'Ивановых']
# similarity rate: 52
#
#
# ['Юля', 'Аня', 'Аня']
# similarity rate: 66
#
#
# ['Георгия', 'Георгия', 'Георгию', 'Георгию', 'Георгий']
# similarity rate: 93
#
#
# ['Сабина', 'Сабина', 'Сабины', 'Сабину', 'Сабины', 'Сабины']
# similarity rate: 90
#
#
# ['Данил', 'Дани', 'Даня', 'Даня', 'Даня', 'Данила', 'Дани', 'Дани', 'Дане', 'Даня']
# similarity rate: 84
#
#
# ['Тани', 'Тане', 'Танюше']
# similarity rate: 78
#
#
# ['Артему', 'Артему', 'Артему', 'Артему']
# similarity rate: 100
#
#
# ['Антонины', 'Антонина', 'Валерии', 'Тони', 'Тони']
# similarity rate: 55
#
#
# ['Араму', 'Арам', 'Арам', 'Арама', 'Арамом', 'Араму', 'Арам', 'Арам', 'Арам', 'Ходжкина', 'Арама', 'Арам', 'Арамом', 'Арам', 'Арам', 'Арам', 'Арам', 'Арам', 'Арама', 'Араму', 'Валерий', 'Евгения']
# similarity rate: 77
#
#
# ['Глебовым', 'Ануару', 'Ануару', 'Петя', 'Петуфок', 'Ануар', 'А', 'Ануар', 'Ануар', 'Ануара', 'Ануар', 'Ануаша', 'Ануара', 'Ануаша', 'Ануару']
# similarity rate: 59
#
#
# ['Дмитрию', 'Дмитрия', 'Дмитрий', 'Дмитрий', 'Дмитрия', 'Дмитрий', 'Дмитрию', 'Дмитрия', 'Дмитрий', 'Дмитрий', 'Дмитрию', 'Дмитрия', 'Дмитрий', 'Харагун', 'Ерофей', 'Дмитрий', 'Дмитрию', 'Дмитрия', 'Ерофей', 'Дмитрию', 'Валерий', 'Анета', 'Азат']
# similarity rate: 64
#
#
# ['Котовой', 'Рената', 'Рената', 'Ренаты', 'Ренату', 'Рената', 'Ренаты', 'Рената', 'Ренаты']
# similarity rate: 77
#
#
# ['Фалелюхина', 'Милана', 'Миланы', 'Милану', 'Регина', 'Милана', 'Милана', 'Миланы', 'Милана', 'Милана']
# similarity rate: 73
#
#
# ['Хрисановых', 'Хрисановы', 'Хрисановы', 'Николай', 'Николая', 'Ники', 'Ника', 'Нике', 'Хрисановы']
# similarity rate: 66
#
#
# ['Айсылу', 'Айсылу', 'Юинга', 'Айсылу', 'Шариповых', 'Айсылу', 'Айсылу', 'Альфия', 'Айсылу', 'Айсылу', 'Айсылу', 'Айсылу', 'Айсылу']
# similarity rate: 58
#
#
# ['Инна', 'Инной', 'Инна', 'Инна']
# similarity rate: 78
#
#
# ['Владика', 'Владика', 'Владика', 'Владик']
# similarity rate: 97
#
#
# ['Екатерины', 'Натальи', 'Наталья', 'Натальи', 'Виталия']
# similarity rate: 67
#
#
# ['Маша', 'Машеньки', 'Маша', 'Маша', 'Маша', 'Маша', 'Деду', 'Маша', 'Машенька', 'Маши', 'Маша', 'Маша', 'РехабМедикал', 'Маша', 'Маши', 'Маши', 'Маши', 'Маше']
# similarity rate: 64
#
#
# ['Нарине', 'Нины']
# similarity rate: 60
#
#
# ['Толкачевой', 'Толкачева', 'Роберт']
# similarity rate: 56
#
#
# ['Грачевых', 'Илья', 'Арина', 'Арина', 'Илья', 'Илья', 'Арина', 'Елена', 'Ульяна', 'Ульяна', 'Ульяна', 'Матвей', 'Матвей', 'Матвей', 'Матвей']
# similarity rate: 58
#
#
# ['Паша', 'Семён', 'Паша', 'Паша', 'Паши', 'Паши', 'Паша', 'Паши', 'Паше', 'Паши', 'Паши', 'Паша', 'Паша', 'Паши', 'Анна', 'Семён', 'Анна', 'Паша', 'Паша', 'Паша', 'Паша', 'Паша', 'Пашу', 'Пашу', 'Паша', 'Паша', 'Паша', 'Паша']
# similarity rate: 73
#
#
# ['Марков', 'Маркова', 'Щирова', 'Маркова']
# similarity rate: 72
#
#
# ['Нилу', 'Нила', 'Нилу', 'Нил', 'Нилу', 'Нила', 'Нилу']
# similarity rate: 79
#
#
# ['Артеме', 'Артеме', 'Артём', 'Артёма', 'Артёму', 'Артём', 'Артем', 'Артем', 'Артем', 'Артема', 'Артёма', 'Артему']
# similarity rate: 87
#
#
# ['Даниила', 'Даниила', 'Дане']
# similarity rate: 78
#
#
# ['Евграфов', 'Артем', 'Артем', 'Артема', 'Артема', 'Артема', 'Нина', 'Артёму']
# similarity rate: 61
#
#
# ['Ирина', 'Марина', 'Алина', 'Артем', 'Артемка', 'Артем', 'Артемки', 'Артем', 'Артем', 'Артема', 'Артема', 'Артемом', 'Артемка', 'Артема']
# similarity rate: 78
#
#
# ['Клоуна', 'Карлсона']
# similarity rate: 71
#
#
# ['Михайловых', 'Егорушка', 'Егору', 'Егор', 'Егор', 'Егор', 'Егору']
# similarity rate: 78
#
#
# ['Юрия', 'Ксению', 'Ксения', 'Михаил', 'Сергей', 'Сергей', 'Сергей', 'Татьяны', 'Татьяна']
# similarity rate: 51
#
#
# ['Косарев', 'Денис', 'Дениса', 'Денис', 'Денису', 'Денис', 'Денис', 'Денис', 'Дениса']
# similarity rate: 84
#
#
# ['Деда', 'Дедушке', 'Дедушка']
# similarity rate: 70
#
#
# ['Федор', 'Федор', 'Федора', 'Федор', 'Федор', 'Федором', 'Федором', 'Александр']
# similarity rate: 86
#
#
# ['Совы', 'Совы', 'Совы', 'Совы', 'Совы', 'Совы', 'Совы', 'Совы', 'Совы', 'Совы', 'Совы', 'Совы']
# similarity rate: 100
#
#
# ['СРОЧНО', 'Грушакевич', 'Грушакевич', 'Насти', 'Настя', 'Настя', 'Настюша', 'Насте', 'Настюша', 'Насте']
# similarity rate: 64
#
#
# ['Миша', 'Маша']
# similarity rate: 75
#
#
# ['Ольги', 'Ольга', 'Ольги', 'Вика', 'Ольга']
# similarity rate: 51
#
#
# ['Самире', 'Самира', 'Тишку', 'Самира', 'Камиле', 'Самира', 'Самиры', 'Самира', 'Самире']
# similarity rate: 58
#
#
# ['Камилле', 'Камилле', 'Елена', 'Елену', 'Камилла', 'Камилла', 'Камилле']
# similarity rate: 69
#
#
# ['Виктория', 'Бонифаций', 'Бонифация']
# similarity rate: 56
#
#
# ['Ирина', 'Оля', 'Олечке', 'Оли', 'Оли', 'Оля', 'Оля', 'Оле']
# similarity rate: 60
#
#
# ['Тимоше', 'Тимоше', 'Тимоше', 'Тимофея', 'Регина', 'Тимофею', 'Тимоша', 'Тимофей', 'Тимоше', 'Сиван', 'Тимоши', 'Тимоши', 'Тимоши']
# similarity rate: 62
#
#
# ['Адели', 'Марат', 'Марату', 'Маратик', 'Марата', 'Эльвира']
# similarity rate: 55
#
#
# ['Арсену', 'Арсен', 'Чуковского', 'Арсен', 'Арсен']
# similarity rate: 54
#
#
# ['Савелий', 'Савве', 'Саввы', 'Юлия', 'Савелия', 'Савелия', 'Савва', 'Саввы', 'Юлия', 'Савва', 'Савва', 'Савелий', 'Савве', 'Савве']
# similarity rate: 58
#
#
# ['Адели', 'Вася', 'Вася', 'Васенька', 'Марат', 'Марат', 'Марат', 'Марат']
# similarity rate: 69
#
#
# ['Мусакаевой', 'Аделина', 'Аделины', 'Аделина', 'Аделиной', 'Аделины', 'Альфира', 'Аделины', 'Аделина', 'Аделины', 'Аделине', 'Аделины', 'Авегра', 'Аделине']
# similarity rate: 64
#
#
# CPU times: user 721 ms, sys: 108 ms, total: 829 ms
# Wall time: 946 ms

# %%
mydf # проверяем: все записалось
# Out:
#                                               Title  \
# 0                                     Подарим жизнь
# 1     Оплата нянечек для отказных детей в больницах
# 2      Оплата нянь для детей-отказников в больницах
# 3                "Не вешай нос! Или право на жизнь"
# 4       Календарь реабилитационного центра для птиц
# ...                                             ...
# 2033     Поможем вместе двойняшкам Артемию и Арине!
# 2034                                Пункт кормления
# 2035  SMG & Bees AWARDS 2020 Москва,Vegas City Hall
# 2036                Город мастеров: швейный цех 2.0
# 2037                 "Дом совы" для особенных детей
#
#                                                  Author  \
# 0     Бобруйское общественное объединение защиты жив...
# 1                 Благотворительный фонд "Дети без мам"
# 2                 Благотворительный фонд "Дети без мам"
# 3     Местная общественная организация защитников жи...
# 4                                         Вера Пахомова
# ...                                                 ...
# 2033                                      БФ Милосердие
# 2034                              СРОО Пункт Милосердия
# 2035                      Благотворительный фонд "АННА"
# 2036                               АНО "Открытый город"
# 2037             Благотворительный фонд "Дорога к дому"
#
#                                             Description  \
# 0     Друзья, рады приветствовать на странице нашего...
# 1     Когда ребёнок серьёзно болен, он ложится в бол...
# 2     В больницах живут малыши, оставшиеся без попеч...
# 3     И снова здравствуйте, Друзья! \nМеня зовут Над...
# 4     Привет, друг! Мы снова на Planeta.ru!) \n  В н...
# ...                                                 ...
# 2033  Благотворительный фонд помощи детям и инвалида...
# 2034  Здравствуйте! Меня зовут Снежана! Мне 35 лет. ...
# 2035  Друзья!\nУже в третий раз мы проводим междунар...
# 2036  Знакомьтесь, это мы - "Город мастеров" - инклю...
# 2037  Как часто мы слышим выражение "особенные дети"...
#
#                                                 Briefly      Goal  Result  \
# 0     Спасение животных от эвтаназии на 5 сутки посл...   10000.0   76100
# 1     Сбор средств на оплату ухода за детьми-сиротам...  150000.0  711665
# 2     Сбор средств на уход за детьми-отказниками в б...   50000.0  236257
# 3     Цель проекта - ликвидировать долги за ветерина...   29395.0   95300
# 4     "Воронье Гнездо" собирает средства на печать к...   15000.0   42550
# ...                                                 ...       ...     ...
# 2033  7 декабря малышам исполнится 5 лет. Давайте сд...  120268.0       0
# 2034  В "Пункте кормления" готовятся и БЕСПЛАТНО раз...  333600.0     421
# 2035  Bees Media Group проводит церемонию вручений п...  300000.0       0
# 2036  "Город мастеров" - инклюзивные мастерские из Е...  200000.0     451
# 2037  «Дом совы» предназначен для коррекции нарушени...  319999.0    1401
#
#       Donations             Start            Finish  LengthZn  ...  \
# 0            67  11 сентября 2017     9 ноября 2017      1134  ...
# 1           470       1 июля 2014  16 сентября 2014      1749  ...
# 2           202   14 октября 2013    16 января 2014      1693  ...
# 3           170   21 февраля 2017    21 апреля 2017      2138  ...
# 4            87     9 ноября 2019    8 декабря 2019      1765  ...
# ...         ...               ...               ...       ...  ...
# 2033          0   17 октября 2019    10 января 2020      1952  ...
# 2034          3   26 февраля 2020     31 марта 2020      4016  ...
# 2035          0   22 декабря 2019    18 января 2020      1453  ...
# 2036          4    6 февраля 2020    15 апреля 2020      1734  ...
# 2037          6   17 февраля 2020    16 апреля 2020      3013  ...
#
#           Started     Finished  \
# 0     11 Sep 2017   9 Nov 2017
# 1      1 Jul 2014  16 Sep 2014
# 2     14 Oct 2013  16 Jan 2014
# 3     21 Feb 2017  21 Apr 2017
# 4      9 Nov 2019   8 Dec 2019
# ...           ...          ...
# 2033  17 Oct 2019  10 Jan 2020
# 2034  26 Feb 2020  31 Mar 2020
# 2035  22 Dec 2019  18 Jan 2020
# 2036   6 Feb 2020  15 Apr 2020
# 2037  17 Feb 2020  16 Apr 2020
#
#                                                 LeadBag DaysLong Cluster  \
# 0     ['спасение', 'животное', 'эвтаназия', 'сутки',...       59       7
# 1     ['сбор', 'средство', 'оплата', 'уход', 'ребёно...       77       0
# 2     ['сбор', 'средство', 'уход', 'ребёнок', 'отказ...       94       0
# 3     ['цель', 'проект', 'ликвидировать', 'долг', 'в...       59       7
# 4     ['воронья', 'гнездо', 'собирать', 'средство', ...       29       4
# ...                                                 ...      ...     ...
# 2033  ['декабрь', 'малыш', 'исполниться', 'год', 'да...       85       1
# 2034  ['пункт', 'кормление', 'готовиться', 'бесплатн...       34       4
# 2035  ['проводить', 'церемония', 'вручение', 'премия...       27       4
# 2036  ['город', 'мастер', 'инклюзивный', 'мастерский...       69      12
# 2037  ['дом', 'сова', 'предназначить', 'коррекция', ...       59      10
#
#                                   Category    Rate  \
# 0                                 животные  1290.0
# 1     сироты_дети_из_неблагополучных семей  9240.0
# 2     сироты_дети_из_неблагополучных семей  2510.0
# 3                                 животные  1620.0
# 4        активизм_просвещение_профилактика  1470.0
# ...                                    ...     ...
# 2033             дети_лечение_реабилитация     0.0
# 2034                      бездомные_кризис    10.0
# 2035     активизм_просвещение_профилактика     0.0
# 2036              социализация_возможности    10.0
# 2037             дети_лечение_реабилитация    20.0
#
#                                                   Names    Adr  NamesSimRate
# 0                                             ['Эгиды']  False             0
# 1                                                    []  False             0
# 2     ['Зою', 'Ксану', 'Анну', 'Юрия', 'Фёдора', 'Ал...  False            11
# 3     ['Надежда', 'Кипиш', 'Островка', 'Маня', 'Хрюн...  False            35
# 4                                                    []  False             0
# ...                                                 ...    ...           ...
# 2033  ['Арине', 'Теме', 'Наталья', 'Арина', 'Артемий...  False            42
# 2034                                        ['Снежана']  False             0
# 2035  ['Авраам', 'Татьяна', 'Наташа', 'Бьянка', 'Нар...  False            24
# 2036                                                 []  False             0
# 2037                ['РЕБЕНОК', 'Соволента', 'Карабин']  False             6
#
# [2038 rows x 23 columns]

# %%
mydf[mydf['Adr']=='True'] # все верно, если NamesSimRate >50, то в Adr - True
# Out:
#                                               Title  \
# 6      Построим вместе! Печь для приготовления каши
# 14    Защитим Кислухинский заказник от браконьеров!
# 15                    Помочь Вадиму встать на ноги!
# 23             Сбор средств на коляску для пса Лаки
# 26                           Нежная "бабочка" Диана
# ...                                             ...
# 2003                         Дети-ангелы среди нас!
# 2004                   Поможем Арсену начать ходить
# 2020                     Волшебный костюм для Саввы
# 2027                      Как помочь детям-ангелам?
# 2031                   Поможем Аделине победить РАК
#
#                                                  Author  \
# 6     Местная общественная организация защитников жи...
# 14                             МОО "Экологический клуб"
# 15                     Благотворительный фонд "Золотце"
# 23                                       Бумеранг Добра
# 26                Благотворительный Фонд "Дети-бабочки"
# ...                                                 ...
# 2003                                БФ "Подари ЗАВТРА!"
# 2004  Свердловская региональная общественная некомме...
# 2020                                БФ "Подари ЗАВТРА!"
# 2027                                БФ "Подари ЗАВТРА!"
# 2031          Благотворительный фонд "Милосердие детям"
#
#                                             Description  \
# 6     Меня зовут Надежда Николаевна, я директор Мест...
# 14    Здравствуйте, друзья!\nМы приглашаем вас к уча...
# 15    Добрый, день друзья!\nНаш Благотворительный фо...
# 23    Здравствуйте, меня зовут Алиса Корецкая ,я вол...
# 26    Двухлетняя Диана из Сургута - ребенок-бабочка....
# ...                                                 ...
# 2003  Благотворительный фонд «Подари ЗАВТРА!» был ос...
# 2004  Арсену 7 лет, он родился недоношенным. \nВо вр...
# 2020  Благотворительный фонд «Подари ЗАВТРА!» был ос...
# 2027  Благотворительный фонд «Подари ЗАВТРА!» был ос...
# 2031  Благотворительный фонд "Милосердие детям" рабо...
#
#                                                 Briefly      Goal  Result  \
# 6     Центр реабилитации для собак "Островок надежды...   46365.0  104500
# 14    Кислухинский лес, его обитатели и егерь Сергей...  380000.0  654200
# 15    Реабилитационный курс для мальчика с детский ц...   16500.0   28165
# 23    Собаке-инвалиду Лаки после огнестрельного ране...   16000.0   24250
# 26    Диана - девочка-бабочка. От рождения ее кожа о...  180000.0  264772
# ...                                                 ...       ...     ...
# 2003  Дети-ангелы - это искренние, добрые и любящие ...  450000.0     500
# 2004  Сбор средств на приобретение ходунков для мале...  103000.0       0
# 2020  Благотворительный фонд "Подари ЗАВТРА!" призыв...   38700.0       0
# 2027  Помочь детям-ангелам очень просто – принять уч...  100000.0       0
# 2031  Знакомьтесь, это Аделина, ей 17 лет и у нее ра...  159273.0       0
#
#       Donations             Start           Finish  LengthZn  ...  \
# 6           217    15 ноября 2016  15 декабря 2016      2548  ...
# 14          936   16 декабря 2015  10 февраля 2016      4318  ...
# 15           52   18 февраля 2017    10 марта 2017      1518  ...
# 23           32   20 декабря 2016  31 декабря 2016      1410  ...
# 26          247       6 июля 2015   4 октября 2015      1635  ...
# ...         ...               ...              ...       ...  ...
# 2003          4  19 сентября 2018  10 декабря 2018      1741  ...
# 2004          0  27 сентября 2018   30 ноября 2018      1399  ...
# 2020          0     13 марта 2019    15 марта 2019      1721  ...
# 2027          0      24 июня 2019     29 июля 2019      2101  ...
# 2031          0   10 октября 2019  15 октября 2019      2336  ...
#
#           Started     Finished  \
# 6     15 Nov 2016  15 Dec 2016
# 14    16 Dec 2015  10 Feb 2016
# 15    18 Feb 2017  10 Mar 2017
# 23    20 Dec 2016  31 Dec 2016
# 26     6 Jul 2015   4 Oct 2015
# ...           ...          ...
# 2003  19 Sep 2018  10 Dec 2018
# 2004  27 Sep 2018  30 Nov 2018
# 2020  13 Mar 2019  15 Mar 2019
# 2027  24 Jun 2019  29 Jul 2019
# 2031  10 Oct 2019  15 Oct 2019
#
#                                                 LeadBag DaysLong Cluster  \
# 6     ['центр', 'реабилитация', 'собака', 'островок'...       30       3
# 14    ['кислухинский', 'лес', 'обитатель', 'егерь', ...       56       4
# 15    ['реабилитационный', 'курс', 'мальчик', 'детск...       20       1
# 23    ['собака', 'инвалид', 'лак', 'огнестрельный', ...       11       7
# 26    ['диана', 'девочка', 'бабочка', 'рождение', 'к...       90      11
# ...                                                 ...      ...     ...
# 2003  ['ребёнок', 'ангел', 'искренний', 'добрый', 'л...       82       1
# 2004  ['сбор', 'средство', 'приобретение', 'ходунок'...       64       1
# 2020  ['благотворительный', 'фонд', 'подарить', 'зав...        2       1
# 2027  ['помочь', 'ребёнок', 'ангел', 'очень', 'прост...       35       1
# 2031  ['знакомиться', 'аделин', 'год', 'рак', 'диагн...        5      11
#
#                        Category     Rate  \
# 6                      животные   3480.0
# 14                     экология  11680.0
# 15    дети_лечение_реабилитация   1410.0
# 23                     животные   2200.0
# 26    дети_лечение_реабилитация   2940.0
# ...                         ...      ...
# 2003  дети_лечение_реабилитация     10.0
# 2004  дети_лечение_реабилитация      0.0
# 2020  дети_лечение_реабилитация      0.0
# 2027  дети_лечение_реабилитация      0.0
# 2031  дети_лечение_реабилитация      0.0
#
#                                                   Names   Adr  NamesSimRate
# 6                   ['Надежда', 'Островка', 'Островка']  True            56
# 14    ['Сергею', 'Сергей', 'Сергей', 'Сергей', 'Серг...  True            94
# 15    ['Вадима', 'Вадюшка', 'Вадику', 'Вадику', 'Вад...  True            78
# 23    ['Алиса', 'Рентген', 'Лаки', 'Лаки', 'Лаки', '...  True            52
# 26    ['Диана', 'Диана', 'Дианочка', 'Дианы', 'Пауль...  True            60
# ...                                                 ...   ...           ...
# 2003  ['Адели', 'Марат', 'Марату', 'Маратик', 'Марат...  True            55
# 2004  ['Арсену', 'Арсен', 'Чуковского', 'Арсен', 'Ар...  True            54
# 2020  ['Савелий', 'Савве', 'Саввы', 'Юлия', 'Савелия...  True            58
# 2027  ['Адели', 'Вася', 'Вася', 'Васенька', 'Марат',...  True            69
# 2031  ['Мусакаевой', 'Аделина', 'Аделины', 'Аделина'...  True            64
#
# [504 rows x 23 columns]

# %%
# del mydf (очистка переменной при необходимости)

# %% [markdown]
# # Итог
# Результат сравнения по расстоянию Левенштена выглядит довольно чистым: списки имен с относительно высоким рейтингом действительно похожи на адресные сборы. Лишние тексты тоже попали в выборку (Например, "Надежда, Отстровок, Островок"), но для дальнейшего исследования это можно поправить в датасете вручную. В любом случае такой подход упрощает задачу такой разметки.
#
# Вероятно, улучшить фильтрацию можно с помощью предвариетельной лемматизации.
